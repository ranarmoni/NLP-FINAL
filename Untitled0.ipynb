# %% [markdown]
# ## Importing the Data

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import *
from sklearn.metrics import confusion_matrix
import pandas_profiling
import pandas as pd

# %%
print("bla bla")

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Constants
DATASET_DIR = 'drive/My Drive/Colab Notebooks/NLPfinal/Automated-Essay--Scoring-master/data/'
GLOVE_DIR = 'drive/My Drive/Colab Notebooks/NLPfinal/Automated-Essay--Scoring-master/glove.6B/'
SAVE_DIR = 'drive/My Drive/Colab Notebooks/NLPfinal/Automated-Essay--Scoring-master/'

import os
import pandas as pd

X = pd.read_csv(os.path.join(DATASET_DIR, 'training_set_rel3.tsv'), sep='\t', encoding='ISO-8859-1')
y = X['domain1_score']
X = X.dropna(axis=1)
X = X.drop(columns=['rater1_domain1', 'rater2_domain1'])

# %%
X.head()
# Out:
#    essay_id  ...  domain1_score
# 0         1  ...              8
# 1         2  ...              9
# 2         3  ...              7
# 3         4  ...             10
# 4         5  ...              8
#
# [5 rows x 4 columns]

# %%
minimum_scores = [-1, 2, 1, 0, 0, 0, 0, 0, 0]
maximum_scores = [-1, 12, 6, 3, 3, 4, 4, 30, 60]

# %% [markdown]
# ## Preprocessing the Data

# %% [markdown]
# We will preprocess all essays and convert them to feature vectors so that they can be fed into the RNN.
#
# These are all helper functions used to clean the essays.

# %%
X_test

# %%
import numpy as np
import nltk
import re
from nltk.corpus import stopwords
from gensim.models import Word2Vec

def essay_to_wordlist(essay_v, remove_stopwords):
    """Remove the tagged labels and word tokenize the sentence."""
    essay_v = re.sub("[^a-zA-Z]", " ", essay_v)
    words = essay_v.lower().split()
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    return (words)

def essay_to_sentences(essay_v, remove_stopwords):
    """Sentence tokenize the essay and call essay_to_wordlist() for word tokenization."""
    tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
    raw_sentences = tokenizer.tokenize(essay_v.strip())
    sentences = []
    for raw_sentence in raw_sentences:
        if len(raw_sentence) > 0:
            sentences.append(essay_to_wordlist(raw_sentence, remove_stopwords))
    return sentences

def makeFeatureVec(words, model, num_features):
    """Make Feature Vector from the words list of an Essay."""
    featureVec = np.zeros((num_features,),dtype="float32")
    num_words = 0.
    index2word_set = set(model.wv.index2word)
    for word in words:
        if word in index2word_set:
            num_words += 1
            featureVec = np.add(featureVec,model[word])        
    featureVec = np.divide(featureVec,num_words)
    return featureVec

def getAvgFeatureVecs(essays, model, num_features):
    """Main function to generate the word vectors for word2vec model."""
    counter = 0
    essayFeatureVecs = np.zeros((len(essays),num_features),dtype="float32")
    for essay in essays:
        essayFeatureVecs[counter] = makeFeatureVec(essay, model, num_features)
        counter = counter + 1
    return essayFeatureVecs

# %% [markdown]
# ## Defining the model

# %% [markdown]
# Here we define a 2-Layer LSTM Model.
#
# Note that instead of using sigmoid activation in the output layer we will use
# Relu since we are not normalising training labels.

# %%
from keras.layers import Embedding, LSTM, Dense, Dropout, Lambda, Flatten
from keras.models import Sequential, load_model, model_from_config
import keras.backend as K

def get_model():
    """Define the model."""
    model = Sequential()
    model.add(LSTM(300, dropout=0.4, recurrent_dropout=0.4, input_shape=[1, 300], return_sequences=True))
    model.add(LSTM(64, recurrent_dropout=0.4))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='relu'))

    model.compile(loss='mean_squared_error', optimizer='rmsprop', metrics=['mae'])
    model.summary()

    return model

# %% [markdown]
# ## Training Phase

# %% [markdown]
# Now we train the model on the dataset.
#
# We will use 5-Fold Cross Validation and measure the Quadratic Weighted Kappa for each fold.
# We will then calculate Average Kappa for all the folds.

# %%
X= X[X["essay_set"].isin([3,4,5,6])]
y = X['domain1_score']

# %%
1trainDataVecs.shape
# Out:
# (5681, 1, 300)

# %%
# !pip install glove_python
# Out:
# Collecting glove_python
#   Downloading https://files.pythonhosted.org/packages/3e/79/7e7e548dd9dcb741935d031117f4bed133276c2a047aadad42f1552d1771/glove_python-0.1.0.tar.gz (263kB)
#      |████████████████████████████████| 266kB 2.8MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from glove_python) (1.16.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from glove_python) (1.3.0)
# Building wheels for collected packages: glove-python
#   Building wheel for glove-python (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/88/4b/6d/10c0d2ad32c9d9d68beec9694a6f0b6e83ab1662a90a089a4b
# Successfully built glove-python
# Installing collected packages: glove-python
# Successfully installed glove-python-0.1.0

# %%
#importing the glove library
from glove import Corpus, Glove

# %%
# creating a corpus object
corpus = Corpus() 
#training the corpus to generate the co occurence matrix which is used in GloVe
corpus.fit(lines, window=10)
#creating a Glove object which will use the matrix created in the above lines to create embeddings
#We can set the learning rate as it uses Gradient Descent and number of components
glove = Glove(no_components=5, learning_rate=0.05)
 
glove.fit(corpus.matrix, epochs=30, no_threads=4, verbose=True)
glove.add_dictionary(corpus.dictionary)
glove.save('glove.model')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-96-d53a9e73b709> in <module>()
# ----> 1 from glove import Corpus, Glove
#       2 # creating a corpus object
#       3 corpus = Corpus()
#       4 #training the corpus to generate the co occurence matrix which is used in GloVe
#       5 corpus.fit(lines, window=10)
#
# ModuleNotFoundError: No module named 'glove'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
sentences
# Out:
# [['features', 'setting', 'affect', 'cyclist', 'many', 'ways'],
#  ['features',
#   'setting',
#   'affect',
#   'cyclist',
#   'lact',
#   'information',
#   'go',
#   'lack',
#   'water'],
#  ['problem', 'needed', 'water', 'trip', 'directions', 'go'],
#  ['features', 'setting', 'affected', 'cyclist', 'negative', 'way'],
#  ['desert', 'dry', 'hot'],
#  ['traveling', 'high', 'deserts', 'california', 'june'],
#  ['kurmaskie', 'num'],
#  ['also',
#   'temperature',
#   'hot',
#   'made',
#   'every',
#   'thing',
#   'around',
#   'hot',
#   'brackish',
#   'water',
#   'faling',
#   'somewhere',
#   'neighborhood',
#   'two',
#   'hundred',
#   'degrees',
#   'kurmaskie',
#   'num'],
#  ['since', 'desert', 'escape', 'sun'],
#  ['text', 'states', 'sun', 'beginning', 'beat', 'kurmaskie', 'num'],
#  ['cyclist',
#   'alone',
#   'road',
#   'none',
#   'around',
#   'either',
#   'passed',
#   'one',
#   'could',
#   'help'],
#  ['growing',
#   'realization',
#   'could',
#   'drop',
#   'heatstroke',
#   'gorgous',
#   'day',
#   'june',
#   'kurmaskie',
#   'num'],
#  ['forty',
#   'miles',
#   'pedal',
#   'arrived',
#   'first',
#   'town',
#   'morning',
#   'fit',
#   'traditional',
#   'definition',
#   'ghost',
#   'town'],
#  ['kurmaskie', 'num'],
#  ['thesettings',
#   'cyclist',
#   'riding',
#   'good',
#   'ones',
#   'negativly',
#   'affected',
#   'causing',
#   'dehydrated',
#   'tiredin',
#   'end'],
#  ['believe',
#   'features',
#   'cyclist',
#   'affected',
#   'impatient',
#   'trustworthy',
#   'tock',
#   'old',
#   'mens',
#   'advice',
#   'take',
#   'hr',
#   'time',
#   'bay',
#   'taking',
#   'short',
#   'cat',
#   'would',
#   'stayed',
#   'true',
#   'mep',
#   'almost',
#   'ared',
#   'heat',
#   'impatientress',
#   'got',
#   'best',
#   'took',
#   'shortcut'],
#  ['experence', 'new', 'haes', 'stat'],
#  ['mep', 'trust', 'people', 'havent', 'seen', 'changes', 'last', 'years'],
#  ['cyclist', 'riding', 'tower', 'stopped', 'directions'],
#  ['old', 'men', 'told', 'take', 'short', 'cut', 'got', 'lost'],
#  ['ghost', 'town', 'desert'],
#  ['conclusion', 'desert', 'hot'],
#  ['affects', 'cyclist', 'change'],
#  ['cut', 'hurt', 'lot', 'people', 'feeling', 'caps', 'care', 'cyclist'],
#  ['one', 'people', 'care', 'cause', 'affect', 'anyone', 'know'],
#  ['big', 'deal', 'write', 'people', 'caps', 'blow', 'stuff'],
#  ['talking', 'tiv', 'radio', 'making', 'stuff', 'say', 'made'],
#  ['believe', 'see'],
#  ['caps', 'black', 'people', 'anything', 'us'],
#  ['really', 'care', 'affects', 'cyclist'],
#  ['essay',
#   'rough',
#   'road',
#   'ahead',
#   'exceed',
#   'posted',
#   'speed',
#   'limit',
#   'describes',
#   'man',
#   'bicycle',
#   'ride',
#   'california'],
#  ['california', 'hot', 'summer', 'cyclist', 'riding'],
#  ['setting', 'greatly', 'affects', 'man', 'journey'],
#  ['made', 'difficult', 'finish', 'ride'],
#  ['drank', 'water', 'beginning', 'ride', 'gets', 'dehydrated'],
#  ['text',
#   'states',
#   'water',
#   'bottles',
#   'contained',
#   'tantalizing',
#   'sips',
#   'see',
#   'setting',
#   'makes',
#   'man',
#   'bikeride',
#   'hard'],
#  ['story',
#   'rough',
#   'road',
#   'ahead',
#   'exceed',
#   'posted',
#   'speed',
#   'limit',
#   'written',
#   'joe',
#   'kurmaskie',
#   'represents',
#   'certain',
#   'conditions',
#   'affect',
#   'cyclist'],
#  ['cyclist',
#   'biking',
#   'desert',
#   'reach',
#   'yosemite',
#   'national',
#   'park',
#   'journey',
#   'accoutered',
#   'many',
#   'tough',
#   'conditions',
#   'make',
#   'difficult',
#   'get'],
#  ['first', 'desert', 'hot', 'makes', 'travel', 'difficult'],
#  ['example',
#   'text',
#   'states',
#   'sun',
#   'beginning',
#   'beat',
#   'caps',
#   'makes',
#   'task',
#   'difficult',
#   'sun',
#   'drain',
#   'person',
#   'energy'],
#  ['secondly',
#   'trip',
#   'long',
#   'cyclist',
#   'hard',
#   'time',
#   'conserving',
#   'water'],
#  ['instance',
#   'man',
#   'drank',
#   'much',
#   'water',
#   'almost',
#   'ran',
#   'water',
#   'bottle',
#   'contained',
#   'dehydration',
#   'cause',
#   'death'],
#  ['joe', 'kurmaskie', 'story', 'rough', 'road', 'ahead'],
#  ['exceed',
#   'posted',
#   'speed',
#   'limit',
#   'represents',
#   'certain',
#   'conditions',
#   'environment',
#   'affect',
#   'cyclist'],
#  ['setting',
#   'authors',
#   'shortcut',
#   'effected',
#   'performance',
#   'strength',
#   'tremendously'],
#  ['whether',
#   'hills',
#   'heat',
#   'barren',
#   'landscape',
#   'three',
#   'took',
#   'toll',
#   'joe',
#   'kurmaskie'],
#  ['lack',
#   'water',
#   'depleted',
#   'energy',
#   'well',
#   'flat',
#   'road',
#   'repalced',
#   'short',
#   'rolling',
#   'hills',
#   'hills',
#   'tough',
#   'thing',
#   'pass',
#   'since',
#   'joe',
#   'drained',
#   'energy'],
#  ['overcame',
#   'exhaustion',
#   'building',
#   'came',
#   'views',
#   'wiped',
#   'sweat',
#   'eyes',
#   'make',
#   'sure',
#   'mirage',
#   'tried',
#   'get',
#   'excited',
#   'believed',
#   'last',
#   'burst',
#   'energy'],
#  ['manouvered',
#   'hill',
#   'authour',
#   'overcame',
#   'problems',
#   'ne',
#   'faced',
#   'even',
#   'though',
#   'difficult'],
#  ['seems',
#   'written',
#   'piece',
#   'exaggrate',
#   'important',
#   'keep',
#   'going',
#   'want',
#   'give'],
#  ['winston',
#   'churchill',
#   'said',
#   'success',
#   'final',
#   'failure',
#   'fatal',
#   'courage',
#   'takes',
#   'continues',
#   'counts',
#   'believe',
#   'person',
#   'agrees'],
#  ['many', 'features', 'affected', 'cyclist', 'heat', 'lack', 'water'],
#  ['cyclist',
#   'drinking',
#   'lot',
#   'water',
#   'throughout',
#   'story',
#   'ends',
#   'little',
#   'water',
#   'left'],
#  ['eased',
#   'past',
#   'trying',
#   'keep',
#   'balance',
#   'dehydrated',
#   'state',
#   'shows',
#   'prepared',
#   'enough',
#   'water',
#   'trip',
#   'yosemite'],
#  ['without', 'water', 'would', 'die', 'heat'],
#  ['wide',
#   'rings',
#   'dried',
#   'sweat',
#   'circled',
#   'shirt',
#   'growing',
#   'realization',
#   'could',
#   'drop',
#   'heat',
#   'stroke',
#   'states',
#   'caps',
#   'danger',
#   'enough',
#   'water',
#   'system'],
#  ['features', 'water', 'heat', 'affected', 'throughout', 'story'],
#  ['enough',
#   'water',
#   'could',
#   'make',
#   'lose',
#   'sweat',
#   'heat',
#   'making',
#   'lose',
#   'even',
#   'sweat',
#   'cause',
#   'extreme',
#   'heatstroke'],
#  ['features', 'setting', 'affected', 'cyclist', 'many', 'ways'],
#  ['initially',
#   'cyclist',
#   'went',
#   'road',
#   'big',
#   'snake',
#   'middle',
#   'made',
#   'keep',
#   'cations',
#   'unease'],
#  ['furthermore',
#   'desert',
#   'nothing',
#   'around',
#   'gave',
#   'cyclist',
#   'abandoness',
#   'help',
#   'trouble'],
#  ['finally',
#   'cyclist',
#   'greatly',
#   'relieved',
#   'sees',
#   'bait',
#   'store',
#   'people'],
#  ['features', 'setting', 'greatly', 'affected', 'cyclist', 'ride'],
#  ['features',
#   'setting',
#   'rough',
#   'road',
#   'ahead',
#   'exceed',
#   'posted',
#   'speed',
#   'limit',
#   'joe',
#   'kurmaksie',
#   'greatly',
#   'affect',
#   'cyclist',
#   'put',
#   'many',
#   'hardships',
#   'probably',
#   'could',
#   'avoided',
#   'old',
#   'cotagers',
#   'told',
#   'path',
#   'thought',
#   'right',
#   'hard',
#   'get',
#   'right',
#   'place',
#   'features',
#   'setting',
#   'described',
#   'flat',
#   'road',
#   'replaced',
#   'short',
#   'rolling',
#   'hills'],
#  ['essay',
#   'exceed',
#   'posted',
#   'speed',
#   'limit',
#   'author',
#   'joe',
#   'kurmaskie',
#   'uses',
#   'features',
#   'setting',
#   'affect',
#   'cyclist'],
#  ['cyclist',
#   'affected',
#   'features',
#   'sees',
#   'setting',
#   'dessert',
#   'several',
#   'miles',
#   'water',
#   'road',
#   'lot',
#   'hills'],
#  ['cyclist',
#   'could',
#   'affected',
#   'seeing',
#   'dessert',
#   'scenary',
#   'changes',
#   'wahile'],
#  ['look',
#   'one',
#   'scene',
#   'hours',
#   'could',
#   'start',
#   'get',
#   'tired',
#   'bored',
#   'everything'],
#  ['cause', 'drossy', 'bored'],
#  ['also', 'cyclist', 'water', 'none', 'fountains', 'cold', 'water'],
#  ['water', 'dessert', 'could', 'make', 'dehydrate', 'faint'],
#  ['setting', 'story', 'affects', 'cyclist', 'many', 'ways'],
#  ['since',
#   'riding',
#   'california',
#   'desert',
#   'always',
#   'feels',
#   'hot',
#   'always',
#   'constant',
#   'thirst'],
#  ['addition', 'area', 'riding', 'appears', 'quite', 'desolate'],
#  ['finds', 'nothing', 'old', 'abondored', 'buildings'],
#  ['find', 'anyone'],
#  ['people', 'cars', 'sign', 'modern', 'civilization'],
#  ['causes',
#   'feel',
#   'little',
#   'unnerved',
#   'something',
#   'happened',
#   'nobody',
#   'would',
#   'know'],
#  ['especially', 'prevelent', 'become', 'dehydrated'],
#  ['ways', 'cyclist', 'much', 'affected', 'setting'],
#  ['story',
#   'rough',
#   'road',
#   'ahead',
#   'person',
#   'features',
#   'setting',
#   'affect',
#   'cyclist',
#   'many',
#   'ways'],
#  ['one',
#   'way',
#   'setting',
#   'affects',
#   'cyclist',
#   'desert',
#   'cyclist',
#   'drank',
#   'water'],
#  ['example',
#   'text',
#   'states',
#   'hitting',
#   'water',
#   'bottles',
#   'pretty',
#   'regularly',
#   'traveling',
#   'high',
#   'deserts',
#   'california',
#   'june'],
#  ['drink', 'water', 'desert', 'forest'],
#  ['go', 'cycling', 'aware', 'settings', 'around', 'affect'],
#  ['features', 'setting', 'affect', 'cyclist'],
#  ['first',
#   'cyclist',
#   'followed',
#   'old',
#   'codgers',
#   'advice',
#   'get',
#   'yosemite',
#   'national',
#   'park'],
#  ['advice', 'use', 'didnt', 'help', 'end'],
#  ['next', 'tarlike', 'substance', 'oozed', 'thoot', 'going', 'water'],
#  ['terrain',
#   'changed',
#   'short',
#   'rolling',
#   'hills',
#   'wasnt',
#   'helping',
#   'bike',
#   'better'],
#  ['lastly',
#   'tumble',
#   'weeds',
#   'crossed',
#   'path',
#   'ridiculously',
#   'large',
#   'snake',
#   'slowed'],
#  ['road', 'blocks', 'setting', 'affected', 'cyclist'],
#  ['features',
#   'setting',
#   'affect',
#   'cyclist',
#   'lack',
#   'water',
#   'date',
#   'information',
#   'rolling',
#   'hills'],
#  ['date',
#   'information',
#   'would',
#   'probably',
#   'got',
#   'water',
#   'town',
#   'empty',
#   'almost',
#   'empty',
#   'like',
#   'ghost',
#   'town',
#   'cyclist',
#   'said'],
#  ['cyclist',
#   'couple',
#   'things',
#   'racing',
#   'wind',
#   'blowing',
#   'theres',
#   'problem',
#   'follow',
#   'traffic',
#   'law',
#   'ride',
#   'right',
#   'side',
#   'road'],
#  ['exceed',
#   'posted',
#   'speed',
#   'limit',
#   'rough',
#   'setting',
#   'harzardous',
#   'things',
#   'death',
#   'defying',
#   'heat'],
#  ['cyclist', 'endure', 'pain', 'dehydration', 'determination'],
#  ['given', 'bad', 'directions', 'almost', 'caused', 'life'],
#  ['travelling',
#   'desert',
#   'claimed',
#   'temperature',
#   'num',
#   'also',
#   'cyclist',
#   'ration',
#   'water',
#   'ghost',
#   'towns',
#   'character',
#   'passed'],
#  ['used',
#   'nature',
#   'skills',
#   'learned',
#   'began',
#   'suck',
#   'pebbles',
#   'take',
#   'mind',
#   'thirst',
#   'uses',
#   'saliva',
#   'help',
#   'refresh',
#   'throat'],
#  ['throughout',
#   'adventure',
#   'everything',
#   'kept',
#   'young',
#   'man',
#   'getting',
#   'water',
#   'whenever',
#   'water',
#   'faster'],
#  ['survived', 'ever', 'take', 'shortcuts'],
#  ['example',
#   'setting',
#   'affecting',
#   'cyclist',
#   'lock',
#   'water',
#   'ghost',
#   'town',
#   'eliterat'],
#  ['frind',
#   'water',
#   'e',
#   'tar',
#   'like',
#   'substance',
#   'come',
#   'tasted',
#   'like',
#   'battery'],
#  ['left',
#   'go',
#   'rough',
#   'road',
#   'travel',
#   'fast',
#   'leanes',
#   'condition',
#   'road'],
#  ['cyclist', 'hard', 'time', 'geting', 'yosemite', 'national', 'park'],
#  ['sun', 'middle', 'june'],
#  ['hot',
#   'cyclist',
#   'became',
#   'dehydrated',
#   'faster',
#   'would',
#   'cooler',
#   'day'],
#  ['pumped',
#   'handle',
#   'old',
#   'rusted',
#   'water',
#   'pump',
#   'said',
#   'water',
#   'felt',
#   'somewhere',
#   'neighborhood',
#   'two',
#   'hundred',
#   'degrees'],
#  ['cyclist',
#   'also',
#   'deal',
#   'lot',
#   'short',
#   'rolling',
#   'hills',
#   'much',
#   'difficult',
#   'bike',
#   'flat',
#   'roads'],
#  ['top',
#   'everything',
#   'else',
#   'roads',
#   'bad',
#   'condition',
#   'watch',
#   'rocks',
#   'road'],
#  ['well',
#   'would',
#   'put',
#   'like',
#   'weather',
#   'everything',
#   'weather',
#   'make',
#   'tired',
#   'upset',
#   'easy',
#   'angre',
#   'make',
#   'upset',
#   'stress'],
#  ['features', 'setting', 'affect', 'cyclist', 'two', 'way'],
#  ['ways', 'pysical', 'mental'],
#  ['pysical', 'ways', 'features', 'affect', 'cyclist', 'terrain'],
#  ['roads', 'long', 'wiredy', 'could', 'wear', 'cyclist'],
#  ['could',
#   'also',
#   'become',
#   'physically',
#   'tired',
#   'incline',
#   'hill',
#   'steep'],
#  ['gravity', 'egausting'],
#  ['temperature', 'also', 'crusal', 'factor', 'cyclist', 'pysical', 'ability'],
#  ['nobody', 'want', 'feel', 'like', 'sauna', 'bike', 'riding'],
#  ['cyclist', 'also', 'attracted', 'mentally'],
#  ['terrain',
#   'looks',
#   'deserted',
#   'anything',
#   'like',
#   'desert',
#   'byciclist',
#   'instintaniously',
#   'thinks',
#   'dehydration',
#   'death',
#   'people',
#   'see',
#   'dead',
#   'animals',
#   'bones',
#   'would',
#   'think',
#   'could',
#   'die'],
#  ['see',
#   'vulture',
#   'circling',
#   'would',
#   'get',
#   'afraid',
#   'think',
#   'death',
#   'worse',
#   'thing',
#   'knowing',
#   'things',
#   'place',
#   'time'],
#  ['setting', 'affects', 'cyclists'],
#  ['settings', 'story', 'grveling'],
#  ['cyclist', 'riding', 'along', 'sun', 'beginning', 'beat'],
#  ['cyclist', 'began', 'sweat', 'due', 'heat', 'thus', 'drank', 'water'],
#  ['cyclist', 'experiencing', 'major', 'heat', 'sweat', 'dehydration'],
#  ['california', 'desert', 'grveling', 'place', 'especially', 'june'],
#  ['luckily',
#   'cyclist',
#   'come',
#   'camp',
#   'found',
#   'fresh',
#   'food',
#   'water',
#   'would',
#   'eventually',
#   'continue',
#   'way',
#   'yosemite',
#   'national',
#   'park'],
#  ['cyclist',
#   'travelling',
#   'yosemite',
#   'national',
#   'park',
#   'comes',
#   'across',
#   'many',
#   'features',
#   'area',
#   'affects'],
#  ['first',
#   'takes',
#   'directions',
#   'old',
#   'guys',
#   'know',
#   'anything',
#   'changes',
#   'maps',
#   'never',
#   'leave',
#   'porch'],
#  ['first',
#   'affects',
#   'positive',
#   'way',
#   'thought',
#   'good',
#   'shortcut',
#   'yosemite'],
#  ['however',
#   'affect',
#   'later',
#   'came',
#   'negative',
#   'turned',
#   'shortcut',
#   'never',
#   'existed'],
#  ['another',
#   'feature',
#   'affected',
#   'wasted',
#   'setting',
#   'desert',
#   'like',
#   'area'],
#  ['heat', 'made', 'harder', 'ride', 'bike', 'also', 'drank', 'lot', 'water'],
#  ['later', 'resulted', 'becoming', 'dehydrated'],
#  ['positive',
#   'affect',
#   'found',
#   'bait',
#   'shop',
#   'rehydrated',
#   'got',
#   'new',
#   'directions'],
#  ['features', 'setting', 'affect', 'cyclist', 'many', 'ways'],
#  ['setting', 'dessert', 'common', 'knowledge', 'know', 'going', 'hot', 'dry'],
#  ['hot', 'cyclist', 'needs', 'water', 'getting', 'dehydrated'],
#  ['low', 'water', 'dry', 'mouth', 'gets', 'drys'],
#  ['caps',
#   'dessert',
#   'sees',
#   'wild',
#   'sometime',
#   'dangerous',
#   'animals',
#   'story',
#   'sees',
#   'ridiculously',
#   'caps',
#   'diamondbrock',
#   'snake',
#   'believe',
#   'venomous',
#   'caps',
#   'extreme',
#   'heat',
#   'dessert',
#   'realizes'],
#  ['chance', 'dropping', 'heatstroke'],
#  ['caps',
#   'writer',
#   'said',
#   'dessert',
#   'short',
#   'rolling',
#   'hills',
#   'rough',
#   'road',
#   'ahead'],
#  ['would', 'leave', 'worn', 'cyclist'],
#  ['terrain', 'cyclist', 'way', 'affects'],
#  ['features', 'setting', 'affect', 'cyclist', 'many', 'different', 'ways'],
#  ['one', 'example', 'hot', 'sun', 'beating', 'made', 'thirsty'],
#  ['another', 'feature', 'rough', 'road', 'wore', 'cyclist', 'made', 'tired'],
#  ['last',
#   'example',
#   'old',
#   'juice',
#   'factory',
#   'picture',
#   'refreshing',
#   'cup',
#   'juice',
#   'made',
#   'cyclist',
#   'feel',
#   'like',
#   'giving',
#   'thought',
#   'would',
#   'die',
#   'dehydration'],
#  ['reasons',
#   'features',
#   'setting',
#   'affect',
#   'cyclist',
#   'many',
#   'different',
#   'ways'],
#  ['essay',
#   'mshan',
#   'writes',
#   'rough',
#   'rodes',
#   'timit',
#   'cyclist',
#   'overcome',
#   'reach',
#   'caps',
#   'gole'],
#  ['setting',
#   'story',
#   'affected',
#   'cyclist',
#   'making',
#   'dehydrated',
#   'could',
#   'lead',
#   'heatstroke'],
#  ['could',
#   'drop',
#   'heatstroke',
#   'shows',
#   'hot',
#   'feeling',
#   'bad',
#   'could',
#   'dropped',
#   'heatstroke'],
#  ['terrain', 'cyclist', 'journey', 'greatly', 'affects'],
#  ['example',
#   'first',
#   'terrain',
#   'experienced',
#   'hilly',
#   'rather',
#   'flat',
#   'soothing'],
#  ['author',
#   'stated',
#   'rode',
#   'morning',
#   'strong',
#   'legs',
#   'smile',
#   'face',
#   'shows',
#   'energized',
#   'happy'],
#  ['however',
#   'reader',
#   'predict',
#   'journey',
#   'remain',
#   'joyful',
#   'cyclist',
#   'basically',
#   'desert',
#   'summer',
#   'extremely',
#   'hot'],
#  ['cyclist',
#   'experiences',
#   'hilly',
#   'terrain',
#   'sucked',
#   'life',
#   'body',
#   'especially',
#   'water',
#   'left'],
#  ['cyclist',
#   'said',
#   'sometimes',
#   'life',
#   'feel',
#   'cruel',
#   'emphasizing',
#   'cyclist',
#   'mood',
#   'changed',
#   'enthusiastic',
#   'tired',
#   'forlorn'],
#  ['change',
#   'mood',
#   'terrain',
#   'connected',
#   'real',
#   'life',
#   'obstacles',
#   'include',
#   'person',
#   'must',
#   'persevere',
#   'strong',
#   'overcome',
#   'cyclist',
#   'finally'],
#  ['features', 'story', 'great', 'effect', 'cyclist'],
#  ['one', 'feature', 'setting', 'effects', 'cyclist', 'heat'],
#  ['first',
#   'story',
#   'says',
#   'pine',
#   'trees',
#   'cooled',
#   'cyclist',
#   'eventually',
#   'forest',
#   'turned',
#   'desert',
#   'heat',
#   'poured',
#   'make',
#   'hard',
#   'cycle'],
#  ['another', 'feature', 'effected', 'cyclist', 'lack', 'water'],
#  ['moved',
#   'away',
#   'beginning',
#   'point',
#   'cyclist',
#   'drinking',
#   'lots',
#   'water'],
#  ['needed', 'refill', 'water', 'brown', 'hot', 'cyclist', 'take'],
#  ['lack',
#   'water',
#   'plus',
#   'heat',
#   'formed',
#   'one',
#   'giant',
#   'obstacle',
#   'potentialy',
#   'could',
#   'killed',
#   'great',
#   'determination',
#   'cyclist',
#   'got',
#   'troubling',
#   'time'],
#  ['narrator',
#   'story',
#   'goes',
#   'tough',
#   'journey',
#   'insisting',
#   'hope',
#   'challenge',
#   'physical',
#   'pain',
#   'despair',
#   'relief'],
#  ['developed',
#   'settings',
#   'take',
#   'place',
#   'example',
#   'taking',
#   'advice',
#   'old',
#   'men',
#   'campsite',
#   'way',
#   'deserts',
#   'california'],
#  ['almost', 'anywhere', 'else', 'journey', 'could', 'much', 'better'],
#  ['could',
#   'gotten',
#   'reliable',
#   'advice',
#   'place',
#   'towns',
#   'miles',
#   'miles',
#   'apart'],
#  ['also', 'one', 'point', 'reaches', 'snake', 'road'],
#  ['could',
#   'symbolize',
#   'decision',
#   'go',
#   'affect',
#   'outcome',
#   'trip',
#   'perhaps',
#   'decisions',
#   'already',
#   'made'],
#  ['take', 'advice', 'strangers', 'better', 'yet', 'use'],
#  ['irony',
#   'continues',
#   'becomes',
#   'dehydrated',
#   'flat',
#   'land',
#   'turns',
#   'hilly'],
#  ['happen', 'could', 'successful', 'healthy', 'trip'],
#  ['setting',
#   'men',
#   'story',
#   'necessary',
#   'plot',
#   'line',
#   'humour',
#   'possesses'],
#  ['city',
#   'example',
#   'would',
#   'get',
#   'lost',
#   'stranded',
#   'therefore',
#   'would',
#   'story'],
#  ['setting', 'story', 'changes', 'many', 'times'],
#  ['starts', 'area', 'rivers', 'pine', 'trees'],
#  ['cyclist', 'arrives', 'ant', 'town'],
#  ['pounded', 'hot', 'sun', 'along', 'hilly', 'road'],
#  ['much',
#   'water',
#   'left',
#   'cyclist',
#   'uses',
#   'energy',
#   'get',
#   'town',
#   'could',
#   'get',
#   'something',
#   'drink'],
#  ['setting', 'made', 'cyclists', 'journey', 'hard', 'one'],
#  ['features',
#   'settings',
#   'affect',
#   'story',
#   'exceed',
#   'posted',
#   'speed',
#   'limit',
#   'morning',
#   'everyone',
#   'still',
#   'sleep',
#   'wakes',
#   'morning',
#   'something',
#   'pull',
#   'first',
#   'plase',
#   'thinks',
#   'old',
#   'crazy',
#   'thinking',
#   'places',
#   'needs',
#   'fixing',
#   'houses',
#   'falling',
#   'apart'],
#  ['leaves', 'see', 'wide', 'bunch', 'hills'],
#  ['inconclusion', 'would', 'never', 'riding'],
#  ['setting', 'story', 'discouraged', 'biker', 'much'],
#  ['follows',
#   'advice',
#   'elderly',
#   'men',
#   'starts',
#   'journey',
#   'notices',
#   'one',
#   'sight',
#   'building',
#   'car',
#   'structure',
#   'kind',
#   'uses',
#   'tone',
#   'words',
#   'describe',
#   'things',
#   'says',
#   'water',
#   'bottle',
#   'contained',
#   'tantalizing',
#   'sips',
#   'describes',
#   'exhaust',
#   'hard',
#   'journey',
#   'getting'],
#  ['describes',
#   'intense',
#   'heat',
#   'inthe',
#   'desert',
#   'california',
#   'pedaling',
#   'one',
#   'long',
#   'crippling',
#   'hill',
#   'terrain',
#   'make',
#   'rideeasy'],
#  ['factor',
#   'weather',
#   'rolling',
#   'hills',
#   'shortage',
#   'water',
#   'take',
#   'tall'],
#  ['flat', 'terrain', 'cool', 'day', 'would', 'first', 'fine'],
#  ['three',
#   'important',
#   'features',
#   'setting',
#   'effect',
#   'cyclist',
#   'ground',
#   'traveling',
#   'towns',
#   'passes',
#   'availability',
#   'water'],
#  ['ground',
#   'cyclist',
#   'riding',
#   'important',
#   'rougher',
#   'terrain',
#   'hills',
#   'energy',
#   'must',
#   'use',
#   'less',
#   'distance',
#   'travel'],
#  ['person',
#   'riding',
#   'fine',
#   'must',
#   'travel',
#   'rolling',
#   'hills',
#   'consume',
#   'energy',
#   'ehausts',
#   'water',
#   'causes',
#   'dividing',
#   'hope'],
#  ['approaches',
#   'towns',
#   'hope',
#   'increases',
#   'soon',
#   'fades',
#   'due',
#   'realization',
#   'town',
#   'unable',
#   'giving',
#   'relief'],
#  ['pumps', 'water', 'tastes', 'like', 'battery', 'acid', 'hope', 'diminishes'],
#  ['sees', 'bait', 'tackle', 'shop', 'knows', 'make', 'gets', 'recover'],
#  ['three', 'features', 'effects', 'cyclist'],
#  ['story',
#   'rough',
#   'road',
#   'ahead',
#   'exceed',
#   'posted',
#   'limit',
#   'setting',
#   'affected',
#   'cyclist'],
#  ['middle', 'desert', 'summer', 'cyclist', 'low', 'water'],
#  ['old',
#   'men',
#   'gave',
#   'wrong',
#   'directions',
#   'mainly',
#   'old',
#   'guys',
#   'thought',
#   'dies'],
#  ['cyclist',
#   'survives',
#   'heat',
#   'season',
#   'riding',
#   'probably',
#   'bring',
#   'another',
#   'water',
#   'botlle',
#   'nextime'],
#  ['features',
#   'setting',
#   'affect',
#   'cyclist',
#   'like',
#   'road',
#   'bad',
#   'bumps',
#   'made',
#   'much',
#   'harder',
#   'also',
#   'took',
#   'lot',
#   'strength'],
#  ['also',
#   'neighborhood',
#   'two',
#   'hundre',
#   'degrees',
#   'become',
#   'road',
#   'arore',
#   'bunch',
#   'hills'],
#  ['setting', 'puts', 'great', 'deal', 'stress', 'cyclist'],
#  ['biggest', 'issue', 'faces', 'weather'],
#  ['cyclist',
#   'traveling',
#   'high',
#   'deserts',
#   'location',
#   'june',
#   'riding',
#   'bike',
#   'day',
#   'soon',
#   'going',
#   'run',
#   'water'],
#  ['thought',
#   'could',
#   'drink',
#   'water',
#   'drank',
#   'water',
#   'feeling',
#   'somewhere',
#   'neighborhood',
#   'two',
#   'hundred',
#   'degrees',
#   'weather',
#   'hot',
#   'humid',
#   'help',
#   'cyclist',
#   'throughout',
#   'journey'],
#  ['another', 'factor', 'setting', 'affected', 'cyclist', 'terrain'],
#  ['flat',
#   'road',
#   'replaced',
#   'short',
#   'rolling',
#   'hills',
#   'main',
#   'problem',
#   'cyclist',
#   'faced'],
#  ['changes', 'terrain', 'played', 'fact', 'weather', 'cooperate'],
#  ['hills', 'made', 'cyclist', 'work', 'harder', 'therefore', 'use', 'energy'],
#  ['luckily', 'terrain', 'positive', 'affect', 'cyclist', 'well'],
#  ['stones', 'found', 'ground', 'helped', 'keep', 'mind', 'thirst'],
#  ['many',
#   'factors',
#   'setting',
#   'negatively',
#   'positively',
#   'affected',
#   'cyclist',
#   'throughout',
#   'adventure'],
#  ['narration',
#   'rough',
#   'road',
#   'ahead',
#   'solo',
#   'cyclist',
#   'encounters',
#   'several',
#   'challenges',
#   'throughout',
#   'story'],
#  ['changes',
#   'environment',
#   'directly',
#   'affect',
#   'completion',
#   'journey',
#   'health'],
#  ['narrator',
#   'makes',
#   'way',
#   'yosemite',
#   'national',
#   'park',
#   'none',
#   'old',
#   'men',
#   'first',
#   'encounter',
#   'environment',
#   'acknowledges',
#   'deserve',
#   'need',
#   'water'],
#  ['text',
#   'states',
#   'huting',
#   'water',
#   'pretty',
#   'regularly',
#   'high',
#   'deserts',
#   'california',
#   'june'],
#  ['disappointed',
#   'truck',
#   'stop',
#   'water',
#   'supply',
#   'pumps',
#   'adequate',
#   'concumption',
#   'forcing',
#   'link',
#   'elsewhere',
#   'quench',
#   'thirst',
#   'next',
#   'explenced',
#   'rolling',
#   'hills',
#   'exsercising',
#   'energy',
#   'made',
#   'way',
#   'everyone',
#   'still',
#   'need',
#   'water'],
#  ['spend',
#   'lost',
#   'quickness',
#   'thoughts',
#   'crippling',
#   'dyhydration',
#   'distracted'],
#  ['wer',
#   'came',
#   'challenges',
#   'making',
#   'bate',
#   'shop',
#   'heat',
#   'beat',
#   'unmercifully'],
#  ['change',
#   'environment',
#   'challenged',
#   'heath',
#   'created',
#   'obstraction',
#   'nearly',
#   'deterred',
#   'goal'],
#  ['setting', 'affected', 'cyclist', 'lot'],
#  ['one', 'way', 'heat'],
#  ['got', 'hot', 'becoming', 'dehydrated'],
#  ['kept', 'drinking', 'water', 'didnt', 'left'],
#  ['another', 'reason', 'road', 'turned', 'hills', 'made', 'use', 'energy'],
#  ['finally',
#   'help',
#   'hadnt',
#   'seen',
#   'sign',
#   'living',
#   'creatures',
#   'except',
#   'snake',
#   'caps',
#   'setting',
#   'affected',
#   'cyclist'],
#  ['features',
#   'setting',
#   'exceed',
#   'posted',
#   'speed',
#   'limit',
#   'affect',
#   'main',
#   'character',
#   'cyclist'],
#  ['cyclist',
#   'biking',
#   'high',
#   'desert',
#   'california',
#   'june',
#   'naturally',
#   'infereal',
#   'dry',
#   'making',
#   'water',
#   'delicacy'],
#  ['cyclist',
#   'passing',
#   'ghost',
#   'town',
#   'pump',
#   'releases',
#   'tarlike',
#   'substance',
#   'followed',
#   'brackish',
#   'water',
#   'runningout',
#   'precious',
#   'water'],
#  ['surrounding',
#   'landscape',
#   'lonely',
#   'hills',
#   'tumbleweeds',
#   'snakes',
#   'inspire',
#   'confidence'],
#  ['fact',
#   'cyclist',
#   'feels',
#   'l',
#   'cald',
#   'drop',
#   'heat',
#   'stroke',
#   'gorgeous',
#   'day',
#   'june',
#   'finds',
#   'old',
#   'grape',
#   'juice',
#   'factory',
#   'longer',
#   'service',
#   'causing',
#   'anxiousness',
#   'dispare',
#   'l',
#   'experience',
#   'similar',
#   'l',
#   'wat',
#   'walking',
#   'state',
#   'park',
#   'date'],
#  ['freezing',
#   'desolate',
#   'landscape',
#   'snow',
#   'covered',
#   'trees',
#   'made',
#   'feel',
#   'never',
#   'warm',
#   'similar',
#   'cyclist',
#   'environment',
#   'made',
#   'feel',
#   'hes',
#   'wald',
#   'die',
#   'dehydration'],
#  ['seen'],
#  ['setting', 'short', 'story', 'affects', 'cyclist'],
#  ['story',
#   'exceed',
#   'posted',
#   'speed',
#   'limit',
#   'author',
#   'joe',
#   'kurmaskie',
#   'tells',
#   'many',
#   'things',
#   'go',
#   'get'],
#  ['example', 'stops', 'asks', 'directions', 'yosemite', 'state', 'park'],
#  ['get', 'lost'],
#  ['towns'],
#  ['next',
#   'example',
#   'came',
#   'rock',
#   'road',
#   'get',
#   'water',
#   'form',
#   'old',
#   'rusted',
#   'pump',
#   'really',
#   'water',
#   'left',
#   'water',
#   'bottle'],
#  ['think',
#   'features',
#   'setting',
#   'affected',
#   'cyclist',
#   'terrain',
#   'flat',
#   'road',
#   'replaced',
#   'short',
#   'rolling',
#   'hills',
#   'shows',
#   'warm',
#   'trobled',
#   'change',
#   'terrain'],
#  ['also',
#   'fells',
#   'alone',
#   'toiled',
#   'point',
#   'tumbleweed',
#   'crossed',
#   'path',
#   'also'],
#  ['though', 'ghost', 'town'],
#  ['summer',
#   'time',
#   'rattled',
#   'around',
#   'dry',
#   'honeycombs',
#   'detorating',
#   'brain',
#   'felt',
#   'slowly',
#   'dying'],
#  ['also',
#   'though',
#   'losing',
#   'sun',
#   'great',
#   'impact',
#   'wiped',
#   'face',
#   'make',
#   'sure',
#   'seeing',
#   'mirage'],
#  ['hopes',
#   'author',
#   'also',
#   'wants',
#   'us',
#   'hope',
#   'keep',
#   'going',
#   'even',
#   'though',
#   'things',
#   'dont',
#   'look',
#   'good',
#   'keep',
#   'moving',
#   'foward',
#   'never',
#   'look',
#   'back',
#   'alway',
#   'positive',
#   'take',
#   'advanage',
#   'surrounding'],
#  ['message', 'author', 'tries', 'give'],
#  ['heat', 'dry', 'flat', 'features', 'setting', 'effected', 'cyclist'],
#  ['cyclist',
#   'driving',
#   'desert',
#   'noticed',
#   'hot',
#   'would',
#   'become',
#   'dehydrated',
#   'quickley'],
#  ['also', 'dry', 'started', 'get', 'nervous', 'thirsty'],
#  ['flat',
#   'ground',
#   'models',
#   'nothing',
#   'around',
#   'help',
#   'cyclist',
#   'made',
#   'scared'],
#  ['story', 'also', 'metions', 'ghost', 'town'],
#  ['features',
#   'setting',
#   'effects',
#   'cyclist',
#   'way',
#   'auther',
#   'started',
#   'talking',
#   'sound',
#   'beginning',
#   'story'],
#  ['picture', 'looks', 'like', 'hes', 'cecilla', 'ssing', 'ceoos'],
#  ['story', 'goo', 'continue', 'ties', 'reads'],
#  ['sound',
#   'like',
#   'enjoying',
#   'ride',
#   'niuse',
#   'bumpy',
#   'roads',
#   'sparkes',
#   'bor',
#   'counter',
#   'tirst'],
#  ['hes',
#   'sacting',
#   'time',
#   'sec',
#   'add',
#   'perso',
#   'mic',
#   'could',
#   'hou',
#   'old',
#   'timers',
#   'know',
#   'thou',
#   'tailoring',
#   'around',
#   'save',
#   'goo',
#   'take',
#   'advice',
#   'goo',
#   'could',
#   'end',
#   'line',
#   'nidsnes',
#   'transitin',
#   'califend',
#   'feres',
#   'could',
#   'let',
#   'therefore',
#   'dehydrated'],
#  ['essay',
#   'rough',
#   'road',
#   'ahead',
#   'exede',
#   'posted',
#   'speed',
#   'many',
#   'featutres',
#   'setting',
#   'affect',
#   'cyclist'],
#  ['first',
#   'cyclist',
#   'goes',
#   'river',
#   'wich',
#   'wount',
#   'find',
#   'later',
#   'journey',
#   'goes',
#   'along',
#   'journey',
#   'heat',
#   'lack',
#   'water',
#   'starts',
#   'affect'],
#  ['also',
#   'finds',
#   'water',
#   'fountain',
#   'pours',
#   'hot',
#   'water',
#   'flavor',
#   'long',
#   'since',
#   'shut'],
#  ['cyclist', 'affected', 'many', 'features', 'setting'],
#  ['setting', 'effected', 'cyclist', 'great', 'way'],
#  ['snakes',
#   'blocked',
#   'pathways',
#   'hi',
#   'short',
#   'water',
#   'supply',
#   'made',
#   'hard',
#   'continue'],
#  ['felt', 'could', 'drop', 'heatstroke'],
#  ['environment',
#   'information',
#   'old',
#   'man',
#   'made',
#   'ride',
#   'hard',
#   'continue'],
#  ['settings', 'big', 'effect'],
#  ['setting', 'affected', 'cyclist', 'rode', 'conditions'],
#  ['rode', 'messed'],
#  ['cyclist',
#   'well',
#   'prepaired',
#   'adventure',
#   'however',
#   'hot',
#   'enuff',
#   'change',
#   'senary'],
#  ['old',
#   'men',
#   'told',
#   'take',
#   'difficult',
#   'path',
#   'tire',
#   'setting',
#   'changed',
#   'worst'],
#  ['nearly',
#   'powered',
#   'devastating',
#   'hills',
#   'dehydration',
#   'slowly',
#   'creeping',
#   'well'],
#  ['nearly',
#   'packed',
#   'enuff',
#   'water',
#   'supplies',
#   'change',
#   'would',
#   'regret',
#   'later'],
#  ['hills',
#   'steep',
#   'endless',
#   'sun',
#   'hot',
#   'mercilous',
#   'mankind',
#   'even',
#   'worse'],
#  ['change', 'setting', 'affected', 'cyclist'],
#  ['story',
#   'exceed',
#   'posted',
#   'speed',
#   'limit',
#   'features',
#   'setting',
#   'affected',
#   'cyclist'],
#  ['example',
#   'cyclist',
#   'traveled',
#   'miles',
#   'bike',
#   'dealing',
#   'weather',
#   'deserts',
#   'little',
#   'bit',
#   'water',
#   'tired'],
#  ['cyclist',
#   'faced',
#   'many',
#   'hard',
#   'times',
#   'trying',
#   'travel',
#   'bicycle',
#   'one',
#   'point',
#   'another'],
#  ['features', 'setting', 'affect', 'cyclist', 'many', 'ways'],
#  ['cyclist', 'going', 'desert', 'dry', 'old', 'dirty'],
#  ['came',
#   'fork',
#   'sorts',
#   'one',
#   'ramshackle',
#   'shed',
#   'several',
#   'rusty',
#   'pumps',
#   'corral',
#   'hold',
#   'largest',
#   'mule',
#   'greeted'],
#  ['side', 'troubling'],
#  ['wanted',
#   'us',
#   'rusty',
#   'water',
#   'pump',
#   'farlike',
#   'substance',
#   'oozed',
#   'water',
#   'seem',
#   'like',
#   'num',
#   'degrees'],
#  ['two', 'miles', 'next', 'section', 'ride', 'notice', 'terrain', 'changing'],
#  ['flat', 'road', 'replaced', 'short', 'rolling', 'hills'],
#  ['made', 'difficult', 'cyclist', 'ride', 'bike'],
#  ['would', 'make', 'cyclist', 'tired'],
#  ['cyclist', 'moved', 'getting', 'tire', 'water', 'supply', 'going'],
#  ['try', 'keep', 'balance', 'kept', 'riding'],
#  ['setting',
#   'place',
#   'effects',
#   'cyclist',
#   'one',
#   'dry',
#   'cyclist',
#   'would',
#   'ridy',
#   'haurst',
#   'place',
#   'dry',
#   'like',
#   'story',
#   'says',
#   'travelling',
#   'high',
#   'parts',
#   'california',
#   'june',
#   'meaning',
#   'really',
#   'hot',
#   'dry',
#   'second',
#   'would',
#   'animals',
#   'dangerous',
#   'cyclist',
#   'riding',
#   'place',
#   'diamond',
#   'back',
#   'snakes',
#   'says',
#   'text',
#   'toiled',
#   'point',
#   'tumbleweeds',
#   'crossed',
#   'path',
#   'ridiculously',
#   'larger',
#   'skilt',
#   'really',
#   'look',
#   'like',
#   'adiamond',
#   'back',
#   'really',
#   'one',
#   'would',
#   'really',
#   'dangerous',
#   'cyclist',
#   'riding',
#   'type',
#   'dangerous',
#   'places',
#   'matter',
#   'type',
#   'settings',
#   'surrandings',
#   'effect',
#   'cyclist',
#   'bad',
#   'place',
#   'ride'],
#  ['features',
#   'setting',
#   'affect',
#   'cylceist',
#   'ground',
#   'would',
#   'change',
#   'terrian',
#   'lot',
#   'makeing',
#   'difficult',
#   'ride',
#   'speed',
#   'entire',
#   'way'],
#  ['also', 'lack', 'water', 'made', 'hard', 'focus'],
#  ['think',
#   'features',
#   'setting',
#   'affect',
#   'cycleist',
#   'people',
#   'think',
#   'worse',
#   'actually'],
#  ['setting', 'affects', 'cyclist', 'many', 'ways'],
#  ['setting',
#   'affects',
#   'cyclist',
#   'weather',
#   'hot',
#   'humid',
#   'makes',
#   'sweat',
#   'using',
#   'energy',
#   'body',
#   'trying',
#   'stay',
#   'cool'],
#  ['also',
#   'setting',
#   'affects',
#   'cyclist',
#   'water',
#   'top',
#   'sweating',
#   'energy',
#   'water',
#   'refuel',
#   'body',
#   'makes',
#   'hard',
#   'keep',
#   'going'],
#  ['story', 'cyclist', 'going', 'desert', 'california'],
#  ['reason', 'limited', 'water', 'supply'],
#  ['really', 'hot', 'would', 'cause', 'drink', 'lot', 'water'],
#  ['started', 'journey', 'morning', 'sun', 'hot', 'would', 'middle', 'day'],
#  ['started', 'get', 'lot', 'sonny'],
#  ['sun', 'comes', 'heat'],
#  ['rider',
#   'says',
#   'sun',
#   'beginning',
#   'beat',
#   'would',
#   'help',
#   'readers',
#   'realize',
#   'time',
#   'day',
#   'hot'],
#  ['morning',
#   'realize',
#   'got',
#   'afternoon',
#   'realized',
#   'started',
#   'get',
#   'dehydrated'],
#  ['wonderful', 'features', 'settings', 'dramatic', 'affect', 'author'],
#  ['affect', 'bad', 'rather', 'good'],
#  ['first', 'almost', 'unbearable', 'heat'],
#  ['author',
#   'limited',
#   'amount',
#   'water',
#   'used',
#   'lot',
#   'smoltering',
#   'temperatures'],
#  ['another',
#   'feature',
#   'great',
#   'impeidence',
#   'author',
#   'well',
#   'would',
#   'lack',
#   'water',
#   'pumps',
#   'stumbed',
#   'across',
#   'snack'],
#  ['lastly',
#   'would',
#   'tar',
#   'like',
#   'substance',
#   'came',
#   'pump',
#   'author',
#   'tried',
#   'get',
#   'water'],
#  ['also',
#   'brackish',
#   'water',
#   'tasted',
#   'suspiciously',
#   'like',
#   'battery',
#   'acid'],
#  ['cyclist',
#   'traveling',
#   'rough',
#   'part',
#   'california',
#   'hot',
#   'month',
#   'june'],
#  ['author',
#   'describes',
#   'part',
#   'part',
#   'journey',
#   'traveling',
#   'high',
#   'deserts',
#   'california',
#   'june'],
#  ['heat',
#   'sun',
#   'much',
#   'water',
#   'around',
#   'causing',
#   'cyclist',
#   'worry',
#   'health'],
#  ['little',
#   'journey',
#   'realizes',
#   'bad',
#   'could',
#   'get',
#   'find',
#   'water',
#   'soon'],
#  ['author', 'write', 'growing', 'realization', 'could', 'drop', 'heatstroke'],
#  ['cyclist',
#   'run',
#   'water',
#   'sign',
#   'life',
#   'around',
#   'begins',
#   'feel',
#   'month',
#   'never',
#   'make',
#   'desert',
#   'yosemite',
#   'national',
#   'park',
#   'author',
#   'describes',
#   'going',
#   'die',
#   'birds',
#   'would',
#   'pick',
#   'clean'],
#  ['setting',
#   'cyclist',
#   'journey',
#   'greatly',
#   'affected',
#   'percieved',
#   'journey'],
#  ['features', 'setting', 'affect', 'cyclist'],
#  ['biker', 'campground', 'california'],
#  ['saying', 'one', 'could', 'sense', 'dusty', 'place'],
#  ['also', 'story', 'says', 'town', 'abandoned'],
#  ['also',
#   'tells',
#   'us',
#   'place',
#   'cyclist',
#   'diserted',
#   'place',
#   'without',
#   'many',
#   'people',
#   'places',
#   'stop'],
#  ['story', 'also', 'talks', 'snake', 'road'],
#  ['snake',
#   'road',
#   'tells',
#   'one',
#   'town',
#   'desireted',
#   'could',
#   'tell',
#   'town',
#   'deserted',
#   'around',
#   'people',
#   'goin',
#   'towns',
#   'buildings'],
#  ['snake',
#   'road',
#   'town',
#   'must',
#   'empty',
#   'around',
#   'streets',
#   'busy',
#   'snakes',
#   'road'],
#  ['setting',
#   'greatly',
#   'affects',
#   'cyclist',
#   'one',
#   'riding',
#   'short',
#   'rolling',
#   'hills',
#   'arround',
#   'ridiculously',
#   'large',
#   'snake',
#   'hot',
#   'could',
#   'suffer',
#   'heatstroke',
#   'minut'],
#  ['yes', 'author', 'affected', 'setting'],
#  ['features',
#   'setting',
#   'yosemite',
#   'give',
#   'cyclist',
#   'something',
#   'look',
#   'forward',
#   'feature',
#   'sorting',
#   'enduse',
#   'get',
#   'causes',
#   'despaire'],
#  ['soon',
#   'cyclist',
#   'passes',
#   'ghost',
#   'town',
#   'notices',
#   'swettering',
#   'hed',
#   'sun',
#   'early',
#   'endeavers',
#   'trip',
#   'checks',
#   'says',
#   'brely',
#   'noticed',
#   'sun',
#   'cool',
#   'pines',
#   'rushing',
#   'hills',
#   'yosemite',
#   'name',
#   'written'],
#  ['although',
#   'cyclist',
#   'began',
#   'feel',
#   'toll',
#   'trip',
#   'sun',
#   'going',
#   'take',
#   'erased',
#   'morning',
#   'hope',
#   'bealy',
#   'arriving',
#   'yosemite'],
#  ['cyclist',
#   'noticedthe',
#   'sun',
#   'drank',
#   'untill',
#   'water',
#   'supply',
#   'seemed',
#   'low',
#   'striping',
#   'old',
#   'rusty',
#   'water',
#   'pump',
#   'hope',
#   'replenished',
#   'taste',
#   'bitter',
#   'battery',
#   'acid',
#   'caused',
#   'cyclist',
#   'stop',
#   'drinking'],
#  ['rolling',
#   'hills',
#   'sun',
#   'tumbleweds',
#   'nothing',
#   'quech',
#   'cyclist',
#   'thirst',
#   'least',
#   'divert',
#   'assertion'],
#  ['cyclists',
#   'see',
#   'sign',
#   'said',
#   'yosemite',
#   'num',
#   'miles',
#   'away',
#   'spirits',
#   'would',
#   'risen',
#   'instead',
#   'saw',
#   'sign',
#   'said',
#   'rough',
#   'road',
#   'ahead',
#   'nothing',
#   'help'],
#  ['terrain',
#   'poporsed',
#   'easier',
#   'travel',
#   'plenty',
#   'supply',
#   'water',
#   'tune',
#   'passive',
#   'would',
#   'hoped',
#   'instead',
#   'despair',
#   'features',
#   'setting',
#   'caused',
#   'cyclist',
#   'grief',
#   'instead',
#   'hope'],
#  ['rough',
#   'road',
#   'ahead',
#   'exceed',
#   'posted',
#   'speed',
#   'limit',
#   'features',
#   'setting',
#   'affect',
#   'cyclist'],
#  ['many',
#   'visual',
#   'features',
#   'create',
#   'deserted',
#   'area',
#   'thats',
#   'hott',
#   'head'],
#  ['example',
#   'paragraph',
#   'five',
#   'use',
#   'alot',
#   'adjectives',
#   'describe',
#   'abandon',
#   'place'],
#  ['words', 'like', 'ramshackle', 'rusty'],
#  ['also',
#   'often',
#   'lack',
#   'water',
#   'brung',
#   'made',
#   'us',
#   'think',
#   'hott',
#   'california',
#   'desert',
#   'must'],
#  ['also',
#   'heat',
#   'made',
#   'cyclist',
#   'belive',
#   'seeing',
#   'miracle',
#   'saw',
#   'welch',
#   'fruit',
#   'juice',
#   'factory'],
#  ['choice',
#   'visual',
#   'words',
#   'story',
#   'words',
#   'describe',
#   'affected',
#   'cyclist'],
#  ['passage', 'cyclist', 'num', 'different', 'settings'],
#  ['one',
#   'settings',
#   'rough',
#   'terrains',
#   'pass',
#   'lacked',
#   'amount',
#   'water',
#   'another',
#   'setting',
#   'cyclist',
#   'go',
#   'hill',
#   'like',
#   'terrains',
#   'laughing',
#   'taking',
#   'old',
#   'men',
#   'advice',
#   'first',
#   'place',
#   'features',
#   'great',
#   'tall',
#   'cyclist',
#   'body',
#   'strength',
#   'spirit'],
#  ['confidence',
#   'determination',
#   'relief',
#   'success',
#   'able',
#   'overcome',
#   'obstacles'],
#  ['features', 'setting', 'affect', 'cyclist', 'many', 'ways'],
#  ['example',
#   'weather',
#   'california',
#   'june',
#   'hot',
#   'water',
#   'cyclist',
#   'found',
#   'pipes',
#   'hot',
#   'well'],
#  ['text',
#   'says',
#   'somewhere',
#   'neighborhood',
#   'two',
#   'hundred',
#   'degrees',
#   'affected',
#   'water',
#   'drink'],
#  ['another', 'example', 'overcome', 'tumbleweeds', 'snakes'],
#  ['text',
#   'states',
#   'tumbleweeds',
#   'crossed',
#   'path',
#   'ridiculously',
#   'large',
#   'snake',
#   'obstacle',
#   'overcome'],
#  ['another', 'example', 'deserted'],
#  ['text', 'says', 'one', 'sight', 'building', 'car', 'structure', 'kind'],
#  ['setting',
#   'features',
#   'cyclist',
#   'hot',
#   'cold',
#   'could',
#   'affect',
#   'cyclist',
#   'riding'],
#  ['hot', 'cyclist', 'would', 'get', 'exhausted', 'lot', 'faster'],
#  ['cold', 'cyclist', 'would', 'month', 'get', 'sick'],
#  ['also',
#   'windy',
#   'would',
#   'go',
#   'lot',
#   'slower',
#   'going',
#   'wind',
#   'direction'],
#  ['features', 'affected', 'cyclist', 'plenty', 'things'],
#  ['one', 'thing', 'would', 'lack', 'water'],
#  ['text', 'said', 'pump', 'gave', 'water', 'taste', 'like', 'battery', 'acid'],
#  ['another',
#   'one',
#   'would',
#   'surroundings',
#   'changed',
#   'old',
#   'men',
#   'sald',
#   'got',
#   'lost'],
#  ['lost', 'determination', 'find', 'someone', 'say', 'could', 'survive'],
#  ['setting', 'features', 'affect', 'cyclist', 'greatly'],
#  ['desert', 'town', 'abandoned'],
#  ['also',
#   'hits',
#   'sign',
#   'says',
#   'rough',
#   'road',
#   'ahead',
#   'kurmaskie',
#   'pg',
#   'num'],
#  ['makes',
#   'trip',
#   'even',
#   'worse',
#   'make',
#   'big',
#   'hills',
#   'torn',
#   'old',
#   'beaten',
#   'roads'],
#  ['sun', 'beating', 'almost', 'water'],
#  ['features',
#   'setting',
#   'affect',
#   'cyclist',
#   'giving',
#   'obstacles',
#   'overcome',
#   'go',
#   'winding',
#   'hills',
#   'would',
#   'slow',
#   'could',
#   'manuver',
#   'hills',
#   'lose',
#   'control',
#   'bike'],
#  ['heat', 'facing', 'would', 'cause', 'tiredness', 'dehydration'],
#  ['exposed',
#   'sun',
#   'heat',
#   'long',
#   'enough',
#   'get',
#   'sunburn',
#   'suffer',
#   'heat',
#   'stroke'],
#  ['heat', 'stroke', 'fatal', 'anyone', 'especially', 'heart', 'problems'],
#  ['dehydration', 'also', 'fatal'],
#  ['cyclist',
#   'see',
#   'buildings',
#   'would',
#   'able',
#   'tell',
#   'might',
#   'get',
#   'lost'],
#  ['getting',
#   'lost',
#   'also',
#   'lead',
#   'dehydration',
#   'tiredness',
#   'heat',
#   'stroke'],
#  ['rough',
#   'caps',
#   'ahead',
#   'features',
#   'setting',
#   'cyclist',
#   'surroundings',
#   'greatly',
#   'influence'],
#  ['high',
#   'deserts',
#   'california',
#   'june',
#   'climate',
#   'hot',
#   'dry',
#   'miserable'],
#  ['another', 'feature', 'setting', 'affects', 'cyclist', 'middle', 'nowhere'],
#  ['human', 'beings', 'cars', 'buildings', 'miles'],
#  ['also', 'terrain', 'affects', 'biker'],
#  ['road',
#   'starts',
#   'get',
#   'bumpy',
#   'uneven',
#   'causes',
#   'exhaust',
#   'water',
#   'supply',
#   'even',
#   'faster'],
#  ['overall', 'cyclist', 'story', 'greatly', 'affected', 'surroundings'],
#  ['short', 'story', 'cyclist', 'affected', 'setting', 'many', 'ways'],
#  ['author', 'running', 'water', 'throughout', 'whole', 'story'],
#  ['water',
#   'bottles',
#   'contained',
#   'tantalizing',
#   'sips',
#   'limited',
#   'amount',
#   'water',
#   'bottles'],
#  ['travel', 'long', 'distance'],
#  ['two', 'miles', 'next', 'section', 'getting', 'tired', 'quick'],
#  ['also', 'terrain', 'good'],
#  ['noticed',
#   'terrain',
#   'changing',
#   'flat',
#   'road',
#   'replaced',
#   'short',
#   'rolling',
#   'hills',
#   'get',
#   'harder',
#   'harder',
#   'continue',
#   'ride'],
#  ['cyclist',
#   'set',
#   'seeing',
#   'cool',
#   'piney',
#   'trees',
#   'lakes',
#   'saw',
#   'dirt',
#   'snake',
#   'source',
#   'civilization',
#   'worried'],
#  ['affectively', 'see', 'scared'],
#  ['see', 'windy', 'rivers', 'trails', 'hidden', 'beneath', 'kinds', 'trees'],
#  ['see', 'people', 'friendly', 'little', 'forest', 'critters'],
#  ['instead', 'saw', 'rusty', 'color', 'dirt', 'occasional', 'snake'],
#  ['mood', 'affected', 'started', 'lose', 'confidence', 'hope'],
#  ['used', 'new', 'surroundings', 'doubted', 'could', 'even', 'make', 'alive'],
#  ['came',
#   'across',
#   'run',
#   'building',
#   'welch',
#   'factory',
#   'even',
#   'distraught'],
#  ['fortunately', 'find', 'civilization', 'came', 'fishing', 'supply', 'shop'],
#  ['definetly', 'boosted', 'spirits'],
#  ['saved',
#   'thirst',
#   'problem',
#   'assured',
#   'alive',
#   'would',
#   'luckily',
#   'stay',
#   'way',
#   'sat',
#   'wading',
#   'search',
#   'destination'],
#  ['features', 'setting', 'good', 'cyclist'],
#  ['california', 'june', 'hot'],
#  ['pretty', 'much', 'desert'],
#  ['stops', 'water', 'pump', 'finds', 'water', 'except', 'drops'],
#  ['also', 'drops', 'get', 'taste', 'like', 'battery', 'acid'],
#  ['good', 'cyclist'],
#  ['essay',
#   'rough',
#   'road',
#   'ahead',
#   'exceed',
#   'posted',
#   'speed',
#   'limit',
#   'author',
#   'changes',
#   'mood',
#   'telling',
#   'us',
#   'cyclist',
#   'feels',
#   'also',
#   'describing',
#   'environment'],
#  ['leaving',
#   'resevoir',
#   'compground',
#   'feeling',
#   'pretty',
#   'good',
#   'leaving',
#   'serenity',
#   'early',
#   'summer',
#   'evening',
#   'headed',
#   'toward',
#   'cool',
#   'pines',
#   'rushing',
#   'rivers',
#   'yosemite',
#   'beautiful',
#   'setting',
#   'affects',
#   'cyclist',
#   'anticipating',
#   'another',
#   'one'],
#  ['however',
#   'moves',
#   'ghost',
#   'town',
#   'sun',
#   'beginning',
#   'beat',
#   'less',
#   'confident',
#   'becoming',
#   'doubtful',
#   'mens',
#   'advice'],
#  ['however',
#   'still',
#   'optimistic',
#   'finally',
#   'funny',
#   'thriving',
#   'little',
#   'spot',
#   'next',
#   'cyclist',
#   'comes',
#   'one',
#   'ramshackle',
#   'shed',
#   'several',
#   'rusty',
#   'pumps',
#   'coral',
#   'knows',
#   'things',
#   'bad',
#   'shape',
#   'caps',
#   'water'],
#  ['however', 'tarlike', 'substance', 'moves', 'choice'],
#  ['comes',
#   'rough',
#   'road',
#   'tumbleweeds',
#   'ridiculously',
#   'large',
#   'snake',
#   'effects',
#   'cyclist',
#   'letting',
#   'know',
#   'things',
#   'worst',
#   'either',
#   'give',
#   'keep',
#   'pushing'],
#  ['doubt', 'could', 'get', 'worse', 'cyclist'],
#  ['finally',
#   'end',
#   'cyclists',
#   'enters',
#   'rather',
#   'modern',
#   'bathroom',
#   'things',
#   'back',
#   'civilization',
#   'feels',
#   'relaxed',
#   'relieved',
#   'much',
#   'better'],
#  ['settings', 'affect', 'cyclists', 'many', 'reasons'],
#  ['one', 'setting', 'nice', 'rider', 'concentrate', 'scenery', 'pain'],
#  ['also',
#   'setting',
#   'nice',
#   'rider',
#   'would',
#   'probably',
#   'concentrate',
#   'pain',
#   'would',
#   'scenery'],
#  ['another',
#   'thing',
#   'setting',
#   'hilly',
#   'rider',
#   'drive',
#   'month',
#   'feel',
#   'greatest'],
#  ['cyclist',
#   'would',
#   'get',
#   'even',
#   'pain',
#   'plus',
#   'cyclist',
#   'could',
#   'could',
#   'get',
#   'dehydrated',
#   'faster',
#   'setting',
#   'really',
#   'affect',
#   'cyclist'],
#  ['setting',
#   'story',
#   'affected',
#   'cyclist',
#   'going',
#   'obstacles',
#   'get',
#   'town'],
#  ['setting', 'desert', 'california', 'june'],
#  ['cyclist',
#   'also',
#   'lack',
#   'water',
#   'found',
#   'pump',
#   'said',
#   'black',
#   'tasted',
#   'like',
#   'battery',
#   'acid'],
#  ['stopped', 'directions', 'men', 'gave', 'oldest', 'set', 'directions'],
#  ['cyclist', 'said', 'would', 'stick', 'trusty', 'map'],
#  ['text', 'features', 'setting', 'greatly', 'affect', 'cyclist'],
#  ['example',
#   'text',
#   'states',
#   'one',
#   'sight',
#   'building',
#   'structure',
#   'kind',
#   'made',
#   'cyclist',
#   'lonely',
#   'started',
#   'lose',
#   'hope',
#   'finding',
#   'water'],
#  ['secondly',
#   'text',
#   'stated',
#   'ironic',
#   'twist',
#   'building',
#   'abandoned',
#   'years',
#   'easlier',
#   'looks',
#   'welch',
#   'grape',
#   'juice',
#   'factory',
#   'made',
#   'cyclist',
#   'lose',
#   'hope',
#   'thought',
#   'building',
#   'would',
#   'people',
#   'got',
#   'excited'],
#  ['lastly',
#   'text',
#   'states',
#   'grape',
#   'caps',
#   'fish',
#   'camp',
#   'sight',
#   'building',
#   'gave',
#   'cyclist',
#   'hope',
#   'happiness',
#   'finding',
#   'place',
#   'get',
#   'drink'],
#  ['setting', 'features', 'greatly', 'affect', 'cyclist', 'feelings'],
#  ['features',
#   'setting',
#   'made',
#   'cyclist',
#   'ride',
#   'longer',
#   'harder',
#   'expected'],
#  ['cyclist', 'first', 'headed', 'road', 'flat', 'smooth'],
#  ['halfway',
#   'trip',
#   'flat',
#   'road',
#   'replaced',
#   'short',
#   'rolling',
#   'hills',
#   'cyclist',
#   'continues',
#   'pedel',
#   'even',
#   'though',
#   'slowed',
#   'mph'],
#  ['hills', 'made', 'ride', 'slower', 'harder', 'hills'],
#  ['tuoards', 'end', 'hills', 'make', 'long', 'crippling', 'hill'],
#  ['word', 'crippling', 'used', 'show', 'phisical', 'affect', 'hill'],
#  ['hills',
#   'feature',
#   'setting',
#   'made',
#   'cyclist',
#   'ride',
#   'longer',
#   'harder',
#   'phisically',
#   'demanding'],
#  ['numerous', 'features', 'setting', 'effect', 'cycleist'],
#  ['example', 'rough', 'road'],
#  ['nother',
#   'example',
#   'tumble',
#   'weed',
#   'snake',
#   'also',
#   'affected',
#   'cyclist'],
#  ['conclusion', 'reasons', 'setting', 'affects', 'cyclist'],
#  ['setting',
#   'like',
#   'desert',
#   'water',
#   'people',
#   'civilizations',
#   'anywhere',
#   'around'],
#  ['make',
#   'worried',
#   'dies',
#   'know',
#   'one',
#   'know',
#   'days',
#   'weeks',
#   'probably'],
#  ['several', 'features', 'cyclist', 'encountered', 'affected', 'cyclist'],
#  ['example',
#   'several',
#   'rusty',
#   'bumps',
#   'quote',
#   'text',
#   'explaining',
#   'riding',
#   'smooth',
#   'ground',
#   'riding',
#   'rough',
#   'hard',
#   'bumpy',
#   'ground'],
#  ['also',
#   'huge',
#   'lack',
#   'water',
#   'water',
#   'depleted',
#   'even',
#   'go',
#   'speed',
#   'limit',
#   'going',
#   'mph',
#   'could',
#   'going',
#   'mph'],
#  ['rough',
#   'roads',
#   'ahead',
#   'exceed',
#   'posted',
#   'speed',
#   'limit',
#   'another',
#   'quote',
#   'expressing',
#   'dangers',
#   'ride',
#   'risking'],
#  ['things', 'made', 'cyclist', 'uncomfortable', 'dehidrated', 'tired'],
#  ['setting',
#   'rough',
#   'road',
#   'ahead',
#   'exceed',
#   'posted',
#   'speed',
#   'limit',
#   'large',
#   'factor',
#   'story',
#   'actually',
#   'cause',
#   'protagonist',
#   'problem',
#   'throughout'],
#  ['first',
#   'started',
#   'large',
#   'hills',
#   'ride',
#   'making',
#   'work',
#   'harder',
#   'tire',
#   'quickly'],
#  ['next',
#   'big',
#   'problem',
#   'heat',
#   'june',
#   'growing',
#   'realization',
#   'could',
#   'drop',
#   'heatstroke',
#   'gorgeous',
#   'day',
#   'june',
#   'simply',
#   'heat',
#   'really',
#   'bad',
#   'made',
#   'hot',
#   'thus',
#   'depleting',
#   'water',
#   'supply',
#   'needed',
#   'survive',
#   'gave',
#   'large',
#   'almost',
#   'inevitable',
#   'risk',
#   'falling',
#   'heatstroke',
#   'dying'],
#  ['heat',
#   'also',
#   'made',
#   'abandoned',
#   'juice',
#   'factory',
#   'ironic',
#   'bitter',
#   'protagonist'],
#  ['sand',
#   'blasted',
#   'picture',
#   'young',
#   'boy',
#   'pouring',
#   'refreshing',
#   'glass',
#   'juice',
#   'mouth',
#   'could',
#   'still',
#   'seen',
#   'caps',
#   'unbearable',
#   'heat',
#   'water',
# ...
#   'heat',
#   'cyclist',
#   'overcome',
#   'rough',
#   'terrain',
#   'short',
#   'rolling',
#   'hills'],
#  ['made', 'cyclist', 'tired', 'weary'],
#  ['adding',
#   'weakness',
#   'extreme',
#   'heat',
#   'also',
#   'ran',
#   'water',
#   'causing',
#   'become',
#   'dehydrated'],
#  ['wide',
#   'rings',
#   'dried',
#   'sweat',
#   'circled',
#   'shirt',
#   'growing',
#   'realization',
#   'could',
#   'drop',
#   'heat',
#   'stroke',
#   'laugh',
#   'trip',
#   'california',
#   'desert',
#   'greatly',
#   'affected',
#   'cyclist',
#   'causing',
#   'great',
#   'exhaustion',
#   'dehydration'],
#  ['features',
#   'setting',
#   'affect',
#   'cyclist',
#   'climate',
#   'could',
#   'hot',
#   'road',
#   'could',
#   'bumpy',
#   'town',
#   'could',
#   'deserted'],
#  ['example', 'rough', 'road', 'ahead'],
#  ['exceed', 'posted', 'speed', 'limit', 'would', 'hard', 'cyclist', 'thirsty'],
#  ['water', 'probably', 'could', 'barely', 'make', 'hills'],
#  ['town', 'water', 'would', 'thirsty'],
#  ['first',
#   'town',
#   'place',
#   'might',
#   'thriving',
#   'little',
#   'spot',
#   'one',
#   'point',
#   'anthor',
#   'warning',
#   'fit',
#   'outsides',
#   'ghost',
#   'town',
#   'waters'],
#  ['cyclist', 'lost', 'hope', 'california', 'desserts', 'june'],
#  ['cyclist',
#   'started',
#   'lose',
#   'hope',
#   'rusty',
#   'water',
#   'pump',
#   'pumped',
#   'battery',
#   'acid',
#   'tasting',
#   'water'],
#  ['said',
#   'sign',
#   'rough',
#   'road',
#   'ahead',
#   'exceed',
#   'posted',
#   'speed',
#   'limit',
#   'cautious'],
#  ['cyclist', 'thought', 'sure', 'going', 'die'],
#  ['cyclist',
#   'also',
#   'felt',
#   'lonely',
#   'text',
#   'says',
#   'one',
#   'sight',
#   'building',
#   'car',
#   'structure',
#   'kind'],
#  ['cyclist', 'california', 'desert', 'made', 'think', 'going', 'die'],
#  ['rough',
#   'road',
#   'ahead',
#   'exceed',
#   'posted',
#   'speed',
#   'limit',
#   'joe',
#   'kurmaskie',
#   'describes',
#   'trying',
#   'biking',
#   'trip',
#   'california'],
#  ['essay',
#   'describes',
#   'weather',
#   'traveling',
#   'high',
#   'deserts',
#   'california',
#   'june',
#   'month',
#   'directly',
#   'characterice',
#   'weather',
#   'reader',
#   'confin',
#   'clear',
#   'image',
#   'sweltering',
#   'heat',
#   'desert',
#   'summer'],
#  ['author',
#   'comes',
#   'across',
#   'ghost',
#   'town',
#   'followed',
#   'dilapidated',
#   'shack',
#   'finally',
#   'sign',
#   'read',
#   'rough',
#   'road',
#   'ahead',
#   'hope',
#   'finding',
#   'yosemite',
#   'park',
#   'gone'],
#  ['hopelessness',
#   'situation',
#   'made',
#   'author',
#   'want',
#   'give',
#   'thinking',
#   'going',
#   'die',
#   'desert',
#   'dehydration',
#   'exhaustion'],
#  ['related',
#   'anyone',
#   'lost',
#   'unfavorable',
#   'conditions',
#   'feeling',
#   'helplessness',
#   'fear',
#   'goes',
#   'along'],
#  ['feels',
#   'like',
#   'everything',
#   'nothing',
#   'working',
#   'favor',
#   'author',
#   'experiences',
#   'description',
#   'trip',
#   'rough',
#   'road',
#   'ahead',
#   'exceed',
#   'posted',
#   'speed',
#   'limit'],
#  ['setting', 'affects', 'cyclist', 'exhaustion', 'getting'],
#  ['made', 'worse', 'heat', 'sweating', 'also', 'cause', 'dihidration'],
#  ['begin',
#   'feature',
#   'affect',
#   'cyclist',
#   'lack',
#   'water',
#   'shown',
#   'speaker',
#   'says',
#   'tried',
#   'drop',
#   'two',
#   'flavor',
#   'battery',
#   'acid',
#   'thats',
#   'one',
#   'biggest',
#   'factors',
#   'risked'],
#  ['reader',
#   'listened',
#   'followed',
#   'directions',
#   'old',
#   'timers',
#   'faced',
#   'many',
#   'issues',
#   'also',
#   'learned',
#   'leason'],
#  ['began',
#   'ride',
#   'day',
#   'break',
#   'morning',
#   'strong',
#   'legs',
#   'even',
#   'smile',
#   'face'],
#  ['time', 'went', 'soon', 'became', 'close', 'water', 'loss', 'energy'],
#  ['caps',
#   'summer',
#   'day',
#   'made',
#   'sweat',
#   'began',
#   'think',
#   'birds',
#   'would',
#   'pluk',
#   'body',
#   'would',
#   'die',
#   'ride',
#   'yosemite'],
#  ['finally',
#   'got',
#   'town',
#   'soon',
#   'refreashed',
#   'learned',
#   'would',
#   'start',
#   'began',
#   'follow',
#   'way',
#   'getting',
#   'places'],
#  ['features',
#   'setting',
#   'essay',
#   'exceed',
#   'posted',
#   'speed',
#   'limit',
#   'affected',
#   'cyclist',
#   'negative',
#   'way'],
#  ['rode', 'thought', 'negatively', 'alot', 'doubt'],
#  ['cyclist', 'confident', 'thought', 'make'],
#  ['example', 'cyclist', 'notices', 'nothing', 'sight', 'tone', 'changes'],
#  ['one', 'sight', 'building', 'car', 'structure', 'kind'],
#  ['began',
#   'breaking',
#   'ride',
#   'distances',
#   'could',
#   'see',
#   'horizon',
#   'telling',
#   'could',
#   'make',
#   'far',
#   'fine'],
#  ['seemed', 'unsure', 'little', 'nervous'],
#  ['journey', 'continued', 'cyclist', 'loses', 'hope', 'seems'],
#  ['really', 'matter'],
#  ['going',
#   'die',
#   'birds',
#   'would',
#   'pick',
#   'clean',
#   'leaving',
#   'expensive',
#   'outdoor',
#   'gear',
#   'diary',
#   'see',
#   'finishing',
#   'journey',
#   'rides',
#   'middle',
#   'nowhere',
#   'nothing',
#   'seen',
#   'except',
#   'rough',
#   'road',
#   'ahead',
#   'signs'],
#  ['features', 'setting', 'effective', 'cyclist'],
#  ['desert', 'area', 'california', 'limited', 'water', 'supply'],
#  ['hot', 'dry'],
#  ['barely', 'water', 'drink', 'go', 'long', 'way', 'hot', 'humid', 'weather'],
#  ['deficiency', 'water', 'could', 'made', 'became', 'dehydrated'],
#  ['another',
#   'obstacle',
#   'biking',
#   'trip',
#   'yosemite',
#   'national',
#   'park',
#   'hills',
#   'faced'],
#  ['beginning', 'flat', 'terrain', 'hills', 'pedal', 'makes', 'lot', 'harder'],
#  ['one', 'obstacle', 'faced', 'snake', 'ran'],
#  ['setting', 'many', 'obstacles', 'guy'],
#  ['heat', 'lack', 'water', 'might', 'able', 'make', 'little', 'easier'],
#  ['features', 'setting', 'strongly', 'affected', 'cyclist'],
#  ['rolling',
#   'hills',
#   'cyclist',
#   'challenging',
#   'problem',
#   'long',
#   'cripppling'],
#  ['maneuvering',
#   'hill',
#   'would',
#   'take',
#   'lot',
#   'energy',
#   'determination',
#   'cyclist'],
#  ['considering',
#   'cyclist',
#   'already',
#   'tired',
#   'sweating',
#   'riding',
#   'rough',
#   'roads',
#   'passing',
#   'large',
#   'snake',
#   'riding',
#   'rolling',
#   'hills',
#   'would',
#   'extremely',
#   'difficult'],
#  ['features',
#   'setting',
#   'helping',
#   'cyclist',
#   'stay',
#   'healthy',
#   'difficulty',
#   'causing',
#   'cyclist',
#   'become',
#   'dehydrated',
#   'possibly',
#   'drop',
#   'heatsroke'],
#  ['however', 'cyclist', 'kept', 'possitive', 'attitude', 'give'],
#  ['determination',
#   'saved',
#   'felt',
#   'relief',
#   'finally',
#   'came',
#   'across',
#   'gary',
#   'wilbells',
#   'fish',
#   'camp',
#   'conclusion',
#   'features',
#   'setting',
#   'affected',
#   'cyclist',
#   'forced',
#   'work',
#   'extra',
#   'hard',
#   'put',
#   'forth',
#   'effort'],
#  ['determination', 'accomplish', 'anything'],
#  ['features',
#   'setting',
#   'affect',
#   'cyclist',
#   'short',
#   'story',
#   'exceed',
#   'posted',
#   'speed',
#   'limit',
#   'cyclist',
#   'mood',
#   'seems',
#   'change',
#   'road',
#   'setting'],
#  ['narration', 'states', 'large', 'high', 'way', 'sign', 'jumped'],
#  ['read',
#   'rough',
#   'road',
#   'ahead',
#   'exceed',
#   'posted',
#   'speed',
#   'limit',
#   'sometimes',
#   'life',
#   'feel',
#   'cruel',
#   'kurmaskie'],
#  ['slowly',
#   'terrain',
#   'gets',
#   'harder',
#   'harder',
#   'cyclist',
#   'feels',
#   'worse',
#   'worse'],
#  ['every',
#   'time',
#   'believes',
#   'town',
#   'gets',
#   'happy',
#   'dreams',
#   'soon',
#   'crushed'],
#  ['one',
#   'see',
#   'picture',
#   'hard',
#   'cycling',
#   'terrain',
#   'affect',
#   'cyclist',
#   'making',
#   'tired',
#   'due',
#   'lack',
#   'water',
#   'sense',
#   'hopelessness',
#   'feels',
#   'loses',
#   'energy',
#   'believes',
#   'die'],
#  ['features',
#   'setting',
#   'setting',
#   'affected',
#   'cyclist',
#   'signs',
#   'speed',
#   'limits'],
#  ['sign', 'affected', 'speed', 'cyclist'],
#  ['another', 'feature', 'hill', 'route'],
#  ['affected', 'cyclist', 'making', 'tired', 'said', 'wipe', 'sweat', 'eyes'],
#  ['setting', 'huge', 'affect', 'cyclist'],
#  ['one', 'affect', 'lack', 'water', 'area', 'dessert'],
#  ['also', 'lack', 'people', 'area', 'help', 'cyclist'],
#  ['hills',
#   'road',
#   'made',
#   'tougher',
#   'cyclist',
#   'drashed',
#   'little',
#   'energy',
#   'left'],
#  ['also',
#   'sun',
#   'beating',
#   'made',
#   'body',
#   'warm',
#   'making',
#   'harder',
#   'focus',
#   'trying'],
#  ['setting',
#   'rough',
#   'road',
#   'ahead',
#   'non',
#   'excee',
#   'posted',
#   'speed',
#   'limit',
#   'cyclist',
#   'greatly',
#   'affected'],
#  ['beginning',
#   'authour',
#   'enjoying',
#   'nice',
#   'campground',
#   'outside',
#   'lodi',
#   'california',
#   'old',
#   'timers',
#   'told',
#   'cyclist',
#   'directions',
#   'piont',
#   'view',
#   'sounded',
#   'sure',
#   'pointing',
#   'land',
#   'marks',
#   'spouting',
#   'towns',
#   'would',
#   'come',
#   'along',
#   'breezy',
#   'aunt',
#   'cyclist',
#   'used',
#   'information',
#   'better'],
#  ['features',
#   'setting',
#   'affect',
#   'cyclist',
#   'old',
#   'guy',
#   'told',
#   'know',
#   'go'],
#  ['guy', 'like', 'yes', 'sir'],
#  ['good',
#   'map',
#   'change',
#   'man',
#   'riding',
#   'bike',
#   'saw',
#   'towns',
#   'sign',
#   'said',
#   'rough',
#   'road',
#   'ahead'],
#  ['man', 'would', 'always', 'stick', 'future'],
#  ['change', 'saw', 'buildings', 'town', 'going', 'going'],
#  ['think', 'might', 'stick', 'future'],
#  ['story',
#   'cyclist',
#   'faced',
#   'many',
#   'problems',
#   'one',
#   'biggest',
#   'problems',
#   'terrian',
#   'maneuver'],
#  ['terrain',
#   'hilly',
#   'go',
#   'hill',
#   'bike',
#   'tireing',
#   'wears',
#   'faster',
#   'flat',
#   'land',
#   'would',
#   'making',
#   'use',
#   'energy'],
#  ['heat',
#   'also',
#   'unbearable',
#   'making',
#   'harder',
#   'focus',
#   'cyclist',
#   'everything',
#   'could',
#   'keep',
#   'consiese',
#   'manuvering',
#   'threu',
#   'terrain',
#   'deserted',
#   'landscape',
#   'huge',
#   'desert',
#   'rolling',
#   'mountains',
#   'pushed',
#   'forwad',
#   'finding',
#   'civilization',
#   'anywhere',
#   'get',
#   'refill',
#   'water'],
#  ['example',
#   'terrain',
#   'hilled',
#   'would',
#   'made',
#   'easier',
#   'using',
#   'less',
#   'energy',
#   'less',
#   'strain',
#   'legs',
#   'heat',
#   'desert',
#   'beating',
#   'probably',
#   'slowed',
#   'progress',
#   'also'],
#  ['heat',
#   'make',
#   'move',
#   'slower',
#   'cyclist',
#   'moving',
#   'barnest',
#   'road',
#   'shade',
#   'make',
#   'journey',
#   'seem',
#   'longer',
#   'imposible'],
#  ['end',
#   'determination',
#   'got',
#   'threw',
#   'landscape',
#   'could',
#   'get',
#   'water',
#   'needed',
#   'finish',
#   'trip'],
#  ['essay',
#   'features',
#   'setting',
#   'cause',
#   'cyclist',
#   'become',
#   'irritaed',
#   'toward',
#   'old',
#   'men'],
#  ['ten',
#   'essay',
#   'old',
#   'men',
#   'give',
#   'cyclist',
#   'direction',
#   'instead',
#   'using',
#   'map',
#   'takes',
#   'advice'],
#  ['however',
#   'information',
#   'date',
#   'takes',
#   'cyclist',
#   'rolling',
#   'hills',
#   'bumpy',
#   'roads'],
#  ['cyclist',
#   'uses',
#   'energy',
#   'get',
#   'unknown',
#   'towns',
#   'importance',
#   'water'],
#  ['cyclist',
#   'blame',
#   'old',
#   'men',
#   'giving',
#   'directions',
#   'wasted',
#   'energy'],
#  ['however',
#   'showed',
#   'realy',
#   'become',
#   'taking',
#   'advice',
#   'motuising',
#   'credited',
#   'map',
#   'real',
#   'directions'],
#  ['setting', 'riding', 'alot', 'cyclist'],
#  ['opinion', 'think', 'setting', 'important', 'part'],
#  ['short', 'story', 'exceed', 'posted', 'speed', 'limit', 'joe', 'kurmaskie'],
#  ['setting', 'greatly', 'affects', 'cyclist', 'mindset'],
#  ['scenery', 'pretty', 'cheery', 'happy', 'well'],
#  ['shown',
#   'author',
#   'writes',
#   'denyoved',
#   'serenity',
#   'early',
#   'summer',
#   'evening',
#   'quote',
#   'describes',
#   'scenery',
#   'serre',
#   'peaceful',
#   'place'],
#  ['happiness',
#   'found',
#   'first',
#   'part',
#   'quote',
#   'said',
#   'denyoyed',
#   'one',
#   'enjoy',
#   'something',
#   'unless',
#   'happy',
#   'cherry',
#   'mindset'],
#  ['therefore', 'peaceful', 'scery', 'affected', 'cyclist', 'making', 'happy'],
#  ['said', 'merry', 'scenery'],
#  ['found',
#   'author',
#   'says',
#   'point',
#   'tumble',
#   'weeds',
#   'crossed',
#   'path',
#   'growing',
#   'realization',
#   'could',
#   'drop',
#   'heatstroke'],
#  ['quote', 'describes', 'scenery', 'place', 'tumbleweeds'],
#  ['steryotypically', 'tumbleweeds', 'found', 'dreary', 'lonely', 'place'],
#  ['lonely', 'scenery', 'takes', 'full', 'cyclist'],
#  ['becomes',
#   'pessimist',
#   'making',
#   'could',
#   'go',
#   'wrong',
#   'could',
#   'get',
#   'better'],
#  ['found', 'around', 'us', 'every', 'day'],
#  ['poor', 'homeless', 'live', 'low', 'standard', 'living', 'often', 'said'],
#  ['exist', 'affected', 'cyclist'],
#  ['conclusion', 'seeing', 'affects', 'cyclist', 'mindset', 'drastically'],
#  ['features',
#   'setting',
#   'affect',
#   'cyclist',
#   'setting',
#   'changed',
#   'drastically'],
#  ['flat', 'wide', 'open', 'road', 'turned', 'short', 'rolling', 'hills'],
#  ['already',
#   'running',
#   'water',
#   'making',
#   'harder',
#   'power',
#   'determination',
#   'go',
#   'hills'],
#  ['determination',
#   'started',
#   'fade',
#   'started',
#   'see',
#   'wide',
#   'open',
#   'lands',
#   'nothing',
#   'tumbleweeds',
#   'ridiculously',
#   'large',
#   'snakes',
#   'felt',
#   'like',
#   'going',
#   'dehydrate',
#   'sun',
#   'beating',
#   'water',
#   'left'],
#  ['used',
#   'pebbles',
#   'found',
#   'put',
#   'mouth',
#   'help',
#   'circulate',
#   'saliva',
#   'mouth'],
#  ['wishes', 'would', 'choke', 'one', 'feels', 'useless'],
#  ['story',
#   'exceed',
#   'posted',
#   'speed',
#   'limit',
#   'joe',
#   'kurmaskie',
#   'cyclist',
#   'faces',
#   'many',
#   'hardships',
#   'way',
#   'yosemite',
#   'due',
#   'features',
#   'setting'],
#  ['fact', 'hot', 'summer', 'day', 'contributed', 'hardships'],
#  ['little', 'water', 'easier', 'get', 'dehydrated'],
#  ['text',
#   'author',
#   'writes',
#   'could',
#   'drop',
#   'heat',
#   'stroke',
#   'gorgeous',
#   'day',
#   'june',
#   'kurmaskie',
#   'num'],
#  ['lets', 'reader', 'know', 'heat', 'june', 'dangerous', 'cyclist'],
#  ['also',
#   'nobody',
#   'around',
#   'except',
#   'old',
#   'timers',
#   'left',
#   'confines',
#   'perches',
#   'since',
#   'water',
#   'offing',
#   'kurmaskie',
#   'num'],
#  ['narrator',
#   'stresses',
#   'viewpoint',
#   'taking',
#   'directions',
#   'people',
#   'since',
#   'directions',
#   'poor'],
#  ['inferred',
#   'meant',
#   'obviously',
#   'date',
#   'across',
#   'directions',
#   'since',
#   'ones',
#   'gave',
#   'correct'],
#  ['cyclist',
#   'story',
#   'rough',
#   'time',
#   'getting',
#   'destination',
#   'due',
#   'setting'],
#  ['story', 'rough', 'road', 'ahead', 'setting', 'affect', 'cyclist'],
#  ['cyclist',
#   'affected',
#   'lack',
#   'water',
#   'distance',
#   'travel',
#   'hilly',
#   'terrain'],
#  ['water', 'bottles', 'contain', 'tantalizing', 'sips'],
#  ['wide',
#   'rings',
#   'dried',
#   'sweat',
#   'circled',
#   'shirt',
#   'statement',
#   'shows',
#   'water',
#   'tired',
#   'hot'],
#  ['setting', 'affected', 'cyclist', 'lot', 'story'],
#  ['tell', 'cyclist', 'effected'],
#  ['one', 'way', 'heat', 'caused', 'drink', 'ran', 'water'],
#  ['next', 'misleading', 'old', 'guys', 'gave', 'ba', 'directions'],
#  ['another', 'way', 'long', 'distance', 'bad', 'terrain', 'slowing'],
#  ['last', 'reason', 'snake', 'slowed'],
#  ['features', 'setting', 'affect', 'cyclist', 'say', 'nothing'],
#  ['might', 'make', 'want', 'go', 'faster', 'left', 'inner', 'speed', 'demon'],
#  ['really', 'tell'],
#  ['personally', 'think', 'setting', 'ride', 'bike', 'even', 'matter'],
#  ['possibly', 'bicyclist', 'even', 'think'],
#  ['features',
#   'setting',
#   'affect',
#   'cyclist',
#   'cars',
#   'building',
#   'water',
#   'people',
#   'sight'],
#  ['goes', 'flat', 'road', 'rolling', 'hills'],
#  ['even', 'though', 'water', 'determined', 'keep', 'pedeling'],
#  ['rough',
#   'road',
#   'ahead',
#   'exceed',
#   'posted',
#   'speed',
#   'limit',
#   'point',
#   'water',
#   'left',
#   'pretty',
#   'much',
#   'middle',
#   'nowhere'],
#  ['situation', 'would', 'feel', 'hopeless'],
#  ['sign', 'hope'],
#  ['saw', 'endless', 'rolling', 'hills'],
#  ['saw', 'building', 'hills', 'thought', 'home', 'free'],
#  ['pedeled', 'building', 'others', 'abandoned'],
#  ['cyclist', 'thought', 'going', 'die'],
#  ['conclusion',
#   'features',
#   'setting',
#   'greatly',
#   'affected',
#   'cyclist',
#   'seeing',
#   'nothing',
#   'gives',
#   'hope'],
#  ['cars',
#   'buildings',
#   'sides',
#   'probably',
#   'would',
#   'give',
#   'confidence',
#   'case'],
#  ['middle', 'nowhere'],
#  ['finally',
#   'came',
#   'bend',
#   'say',
#   'easily',
#   'randing',
#   'bend',
#   'troubles',
#   'thirst',
#   'fear',
#   'behind'],
#  ['theres', 'many', 'features', 'setting', 'affect', 'cyclest'],
#  ['dehidration', 'started', 'sun', 'beeting', 'thirst', 'water'],
#  ['mainly',
#   'affected',
#   'water',
#   'road',
#   'abbanond',
#   'welchs',
#   'grape',
#   'juice',
#   'factory'],
#  ...]

# %%
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import cohen_kappa_score,accuracy_score

#cv = KFold(len(X), n_folds=5, shuffle=True)
cv = KFold(n_splits=5, shuffle=True)
#cv = k_fold.
results = []
y_pred_list = []

count = 1
for traincv, testcv in cv.split(X):
    print("\n--------Fold {}--------\n".format(count))
    X_test, X_train, y_test, y_train = X.iloc[testcv], X.iloc[traincv], y.iloc[testcv], y.iloc[traincv]
    
    train_essays = X_train['essay']
    test_essays = X_test['essay']
    
    sentences = []
    
    for essay in train_essays:
            # Obtaining all sentences from the training essays.
            sentences += essay_to_sentences(essay, remove_stopwords = True)
            
    # Initializing variables for word2vec model.
    num_features = 300 
    min_word_count = 5
    num_workers = 4
    context = 10
    downsampling = 1e-3

    print("Training Word2Vec Model...")
    model = Word2Vec(sentences, workers=num_workers, size=num_features, min_count = min_word_count, window = context, sample = downsampling)

    model.init_sims(replace=True)
    model.wv.save_word2vec_format('word2vecmodel.bin', binary=True)

    clean_train_essays = []
    
    # Generate training and testing data word vectors.
    for essay_v in train_essays:
        clean_train_essays.append(essay_to_wordlist(essay_v, remove_stopwords=True))
    trainDataVecs = getAvgFeatureVecs(clean_train_essays, model, num_features)
    
    clean_test_essays = []
    for essay_v in test_essays:
        clean_test_essays.append(essay_to_wordlist( essay_v, remove_stopwords=True ))
    testDataVecs = getAvgFeatureVecs(clean_test_essays, model, num_features )
    
    trainDataVecs = np.array(trainDataVecs)
    testDataVecs = np.array(testDataVecs)
    # Reshaping train and test vectors to 3 dimensions. (1 represnts one timestep)
    trainDataVecs = np.reshape(trainDataVecs, (trainDataVecs.shape[0], 1, trainDataVecs.shape[1]))
    testDataVecs = np.reshape(testDataVecs, (testDataVecs.shape[0], 1, testDataVecs.shape[1]))
    
    lstm_model = get_model()
    lstm_model.fit(trainDataVecs, y_train, batch_size=64, epochs=50)
    #lstm_model.load_weights('./model_weights/final_lstm.h5')
    y_pred = lstm_model.predict(testDataVecs)
    
    # Save any one of the 8 models.
    if count == 5:
         lstm_model.save('./model_weights/final_lstm.h5')
    
    # Round y_pred to the nearest integer.
    y_pred = np.around(y_pred)
    
    # Evaluate the model on the evaluation metric. "Quadratic mean averaged Kappa"
    result = accuracy_score(y_test.values,y_pred)
    print("accuracy Score: {}".format(result))
    result = cohen_kappa_score(y_test.values,y_pred,weights='quadratic')
    print("Kappa Score: {}".format(result))
    
    results.append(result)

    count += 1
# Out:
# --------Fold 1--------
#
# Training Word2Vec Model...
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_27 (LSTM)               (None, 1, 300)            721200
# _________________________________________________________________
# lstm_28 (LSTM)               (None, 64)                93440
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 814,705
# Trainable params: 814,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5680/5680 [==============================] - 10s 2ms/step - loss: 1.4086 - mean_absolute_error: 0.9396
# Epoch 2/50
# 5680/5680 [==============================] - 3s 576us/step - loss: 0.9220 - mean_absolute_error: 0.7812
# Epoch 3/50
# 5680/5680 [==============================] - 3s 574us/step - loss: 0.8821 - mean_absolute_error: 0.7623
# Epoch 4/50
# 5680/5680 [==============================] - 3s 570us/step - loss: 0.8621 - mean_absolute_error: 0.7492
# Epoch 5/50
# 5680/5680 [==============================] - 3s 574us/step - loss: 0.8600 - mean_absolute_error: 0.7481
# Epoch 6/50
# 5680/5680 [==============================] - 3s 577us/step - loss: 0.8548 - mean_absolute_error: 0.7463
# Epoch 7/50
# 5680/5680 [==============================] - 3s 577us/step - loss: 0.8422 - mean_absolute_error: 0.7449
# Epoch 8/50
# 5680/5680 [==============================] - 3s 573us/step - loss: 0.8434 - mean_absolute_error: 0.7432
# Epoch 9/50
# 5680/5680 [==============================] - 3s 580us/step - loss: 0.8291 - mean_absolute_error: 0.7354
# Epoch 10/50
# 5680/5680 [==============================] - 3s 572us/step - loss: 0.8227 - mean_absolute_error: 0.7317
# Epoch 11/50
# 5680/5680 [==============================] - 3s 572us/step - loss: 0.8072 - mean_absolute_error: 0.7234
# Epoch 12/50
# 5680/5680 [==============================] - 3s 579us/step - loss: 0.8084 - mean_absolute_error: 0.7256
# Epoch 13/50
# 5680/5680 [==============================] - 3s 575us/step - loss: 0.7966 - mean_absolute_error: 0.7220
# Epoch 14/50
# 5680/5680 [==============================] - 3s 574us/step - loss: 0.7847 - mean_absolute_error: 0.7167
# Epoch 15/50
# 5680/5680 [==============================] - 3s 583us/step - loss: 0.7709 - mean_absolute_error: 0.7105
# Epoch 16/50
# 5680/5680 [==============================] - 3s 576us/step - loss: 0.7781 - mean_absolute_error: 0.7113
# Epoch 17/50
# 5680/5680 [==============================] - 3s 570us/step - loss: 0.7636 - mean_absolute_error: 0.7072
# Epoch 18/50
# 5680/5680 [==============================] - 3s 578us/step - loss: 0.7552 - mean_absolute_error: 0.7026
# Epoch 19/50
# 5680/5680 [==============================] - 3s 568us/step - loss: 0.7449 - mean_absolute_error: 0.6967
# Epoch 20/50
# 5680/5680 [==============================] - 3s 573us/step - loss: 0.7421 - mean_absolute_error: 0.6962
# Epoch 21/50
# 5680/5680 [==============================] - 3s 573us/step - loss: 0.7376 - mean_absolute_error: 0.6926
# Epoch 22/50
# 5680/5680 [==============================] - 3s 571us/step - loss: 0.7339 - mean_absolute_error: 0.6928
# Epoch 23/50
# 5680/5680 [==============================] - 3s 572us/step - loss: 0.7242 - mean_absolute_error: 0.6839
# Epoch 24/50
# 5680/5680 [==============================] - 3s 580us/step - loss: 0.7230 - mean_absolute_error: 0.6850
# Epoch 25/50
# 5680/5680 [==============================] - 3s 590us/step - loss: 0.7129 - mean_absolute_error: 0.6807
# Epoch 26/50
# 5680/5680 [==============================] - 3s 589us/step - loss: 0.7056 - mean_absolute_error: 0.6777
# Epoch 27/50
# 5680/5680 [==============================] - 3s 580us/step - loss: 0.7079 - mean_absolute_error: 0.6792
# Epoch 28/50
# 5680/5680 [==============================] - 3s 575us/step - loss: 0.7087 - mean_absolute_error: 0.6787
# Epoch 29/50
# 5680/5680 [==============================] - 3s 571us/step - loss: 0.6949 - mean_absolute_error: 0.6685
# Epoch 30/50
# 5680/5680 [==============================] - 3s 574us/step - loss: 0.6959 - mean_absolute_error: 0.6725
# Epoch 31/50
# 5680/5680 [==============================] - 3s 579us/step - loss: 0.6800 - mean_absolute_error: 0.6639
# Epoch 32/50
# 5680/5680 [==============================] - 3s 573us/step - loss: 0.6839 - mean_absolute_error: 0.6664
# Epoch 33/50
# 5680/5680 [==============================] - 3s 578us/step - loss: 0.6723 - mean_absolute_error: 0.6610
# Epoch 34/50
# 5680/5680 [==============================] - 3s 579us/step - loss: 0.6683 - mean_absolute_error: 0.6552
# Epoch 35/50
# 5680/5680 [==============================] - 3s 572us/step - loss: 0.6674 - mean_absolute_error: 0.6571
# Epoch 36/50
# 5680/5680 [==============================] - 3s 575us/step - loss: 0.6643 - mean_absolute_error: 0.6563
# Epoch 37/50
# 5680/5680 [==============================] - 3s 584us/step - loss: 0.6706 - mean_absolute_error: 0.6601
# Epoch 38/50
# 5680/5680 [==============================] - 3s 574us/step - loss: 0.6573 - mean_absolute_error: 0.6527
# Epoch 39/50
# 5680/5680 [==============================] - 3s 577us/step - loss: 0.6567 - mean_absolute_error: 0.6545
# Epoch 40/50
# 5680/5680 [==============================] - 3s 579us/step - loss: 0.6484 - mean_absolute_error: 0.6470
# Epoch 41/50
# 5680/5680 [==============================] - 3s 569us/step - loss: 0.6495 - mean_absolute_error: 0.6489
# Epoch 42/50
# 5680/5680 [==============================] - 3s 572us/step - loss: 0.6378 - mean_absolute_error: 0.6395
# Epoch 43/50
# 5680/5680 [==============================] - 3s 582us/step - loss: 0.6427 - mean_absolute_error: 0.6450
# Epoch 44/50
# 5680/5680 [==============================] - 3s 579us/step - loss: 0.6353 - mean_absolute_error: 0.6432
# Epoch 45/50
# 5680/5680 [==============================] - 3s 576us/step - loss: 0.6415 - mean_absolute_error: 0.6433
# Epoch 46/50
# 5680/5680 [==============================] - 3s 569us/step - loss: 0.6329 - mean_absolute_error: 0.6402
# Epoch 47/50
# 5680/5680 [==============================] - 3s 568us/step - loss: 0.6333 - mean_absolute_error: 0.6417
# Epoch 48/50
# 5680/5680 [==============================] - 3s 572us/step - loss: 0.6240 - mean_absolute_error: 0.6365
# Epoch 49/50
# 5680/5680 [==============================] - 3s 577us/step - loss: 0.6311 - mean_absolute_error: 0.6395
# Epoch 50/50
# 5680/5680 [==============================] - 3s 582us/step - loss: 0.6305 - mean_absolute_error: 0.6392
# accuracy Score: 0.4616467276565799
# Kappa Score: 0.6081016678006049
#
# --------Fold 2--------
#
# Training Word2Vec Model...
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_29 (LSTM)               (None, 1, 300)            721200
# _________________________________________________________________
# lstm_30 (LSTM)               (None, 64)                93440
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 814,705
# Trainable params: 814,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5681/5681 [==============================] - 10s 2ms/step - loss: 1.3956 - mean_absolute_error: 0.9363
# Epoch 2/50
# 5681/5681 [==============================] - 3s 573us/step - loss: 0.9267 - mean_absolute_error: 0.7765
# Epoch 3/50
# 5681/5681 [==============================] - 3s 576us/step - loss: 0.9000 - mean_absolute_error: 0.7680
# Epoch 4/50
# 5681/5681 [==============================] - 3s 571us/step - loss: 0.8909 - mean_absolute_error: 0.7667
# Epoch 5/50
# 5681/5681 [==============================] - 3s 566us/step - loss: 0.8591 - mean_absolute_error: 0.7532
# Epoch 6/50
# 5681/5681 [==============================] - 3s 565us/step - loss: 0.8544 - mean_absolute_error: 0.7500
# Epoch 7/50
# 5681/5681 [==============================] - 3s 568us/step - loss: 0.8537 - mean_absolute_error: 0.7473
# Epoch 8/50
# 5681/5681 [==============================] - 3s 566us/step - loss: 0.8445 - mean_absolute_error: 0.7430
# Epoch 9/50
# 5681/5681 [==============================] - 3s 569us/step - loss: 0.8395 - mean_absolute_error: 0.7409
# Epoch 10/50
# 5681/5681 [==============================] - 3s 573us/step - loss: 0.8308 - mean_absolute_error: 0.7335
# Epoch 11/50
# 5681/5681 [==============================] - 3s 570us/step - loss: 0.8146 - mean_absolute_error: 0.7300
# Epoch 12/50
# 5681/5681 [==============================] - 3s 571us/step - loss: 0.8163 - mean_absolute_error: 0.7297
# Epoch 13/50
# 5681/5681 [==============================] - 3s 569us/step - loss: 0.8033 - mean_absolute_error: 0.7239
# Epoch 14/50
# 5681/5681 [==============================] - 3s 568us/step - loss: 0.7919 - mean_absolute_error: 0.7184
# Epoch 15/50
# 5681/5681 [==============================] - 3s 568us/step - loss: 0.7908 - mean_absolute_error: 0.7184
# Epoch 16/50
# 5681/5681 [==============================] - 3s 569us/step - loss: 0.7720 - mean_absolute_error: 0.7100
# Epoch 17/50
# 5681/5681 [==============================] - 3s 567us/step - loss: 0.7571 - mean_absolute_error: 0.7018
# Epoch 18/50
# 5681/5681 [==============================] - 3s 568us/step - loss: 0.7628 - mean_absolute_error: 0.7070
# Epoch 19/50
# 5681/5681 [==============================] - 3s 573us/step - loss: 0.7422 - mean_absolute_error: 0.6965
# Epoch 20/50
# 5681/5681 [==============================] - 3s 568us/step - loss: 0.7453 - mean_absolute_error: 0.6964
# Epoch 21/50
# 5681/5681 [==============================] - 3s 574us/step - loss: 0.7408 - mean_absolute_error: 0.6964
# Epoch 22/50
# 5681/5681 [==============================] - 3s 568us/step - loss: 0.7362 - mean_absolute_error: 0.6960
# Epoch 23/50
# 5681/5681 [==============================] - 3s 576us/step - loss: 0.7291 - mean_absolute_error: 0.6878
# Epoch 24/50
# 5681/5681 [==============================] - 3s 567us/step - loss: 0.7231 - mean_absolute_error: 0.6846
# Epoch 25/50
# 5681/5681 [==============================] - 3s 569us/step - loss: 0.7223 - mean_absolute_error: 0.6870
# Epoch 26/50
# 5681/5681 [==============================] - 3s 578us/step - loss: 0.7098 - mean_absolute_error: 0.6771
# Epoch 27/50
# 5681/5681 [==============================] - 3s 578us/step - loss: 0.7023 - mean_absolute_error: 0.6750
# Epoch 28/50
# 5681/5681 [==============================] - 3s 567us/step - loss: 0.7028 - mean_absolute_error: 0.6759
# Epoch 29/50
# 5681/5681 [==============================] - 3s 575us/step - loss: 0.7032 - mean_absolute_error: 0.6760
# Epoch 30/50
# 5681/5681 [==============================] - 3s 569us/step - loss: 0.6914 - mean_absolute_error: 0.6726
# Epoch 31/50
# 5681/5681 [==============================] - 3s 577us/step - loss: 0.6827 - mean_absolute_error: 0.6665
# Epoch 32/50
# 5681/5681 [==============================] - 3s 593us/step - loss: 0.6822 - mean_absolute_error: 0.6651
# Epoch 33/50
# 5681/5681 [==============================] - 3s 582us/step - loss: 0.6773 - mean_absolute_error: 0.6638
# Epoch 34/50
# 5681/5681 [==============================] - 3s 571us/step - loss: 0.6795 - mean_absolute_error: 0.6658
# Epoch 35/50
# 5681/5681 [==============================] - 3s 574us/step - loss: 0.6696 - mean_absolute_error: 0.6587
# Epoch 36/50
# 5681/5681 [==============================] - 3s 567us/step - loss: 0.6800 - mean_absolute_error: 0.6644
# Epoch 37/50
# 5681/5681 [==============================] - 3s 564us/step - loss: 0.6669 - mean_absolute_error: 0.6557
# Epoch 38/50
# 5681/5681 [==============================] - 3s 562us/step - loss: 0.6709 - mean_absolute_error: 0.6599
# Epoch 39/50
# 5681/5681 [==============================] - 3s 574us/step - loss: 0.6569 - mean_absolute_error: 0.6553
# Epoch 40/50
# 5681/5681 [==============================] - 3s 568us/step - loss: 0.6547 - mean_absolute_error: 0.6530
# Epoch 41/50
# 5681/5681 [==============================] - 3s 567us/step - loss: 0.6398 - mean_absolute_error: 0.6441
# Epoch 42/50
# 5681/5681 [==============================] - 3s 569us/step - loss: 0.6582 - mean_absolute_error: 0.6515
# Epoch 43/50
# 5681/5681 [==============================] - 3s 568us/step - loss: 0.6558 - mean_absolute_error: 0.6494
# Epoch 44/50
# 5681/5681 [==============================] - 3s 568us/step - loss: 0.6471 - mean_absolute_error: 0.6466
# Epoch 45/50
# 5681/5681 [==============================] - 3s 573us/step - loss: 0.6556 - mean_absolute_error: 0.6503
# Epoch 46/50
# 5681/5681 [==============================] - 3s 571us/step - loss: 0.6447 - mean_absolute_error: 0.6469
# Epoch 47/50
# 5681/5681 [==============================] - 3s 562us/step - loss: 0.6356 - mean_absolute_error: 0.6443
# Epoch 48/50
# 5681/5681 [==============================] - 3s 575us/step - loss: 0.6305 - mean_absolute_error: 0.6397
# Epoch 49/50
# 5681/5681 [==============================] - 3s 563us/step - loss: 0.6342 - mean_absolute_error: 0.6425
# Epoch 50/50
# 5681/5681 [==============================] - 3s 561us/step - loss: 0.6263 - mean_absolute_error: 0.6367
# accuracy Score: 0.4753521126760563
# Kappa Score: 0.5850321545669022
#
# --------Fold 3--------
#
# Training Word2Vec Model...
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_31 (LSTM)               (None, 1, 300)            721200
# _________________________________________________________________
# lstm_32 (LSTM)               (None, 64)                93440
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 814,705
# Trainable params: 814,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5681/5681 [==============================] - 11s 2ms/step - loss: 1.4129 - mean_absolute_error: 0.9416
# Epoch 2/50
# 5681/5681 [==============================] - 3s 591us/step - loss: 0.9193 - mean_absolute_error: 0.7746
# Epoch 3/50
# 5681/5681 [==============================] - 3s 576us/step - loss: 0.8949 - mean_absolute_error: 0.7643
# Epoch 4/50
# 5681/5681 [==============================] - 3s 571us/step - loss: 0.8790 - mean_absolute_error: 0.7543
# Epoch 5/50
# 5681/5681 [==============================] - 3s 574us/step - loss: 0.8711 - mean_absolute_error: 0.7490
# Epoch 6/50
# 5681/5681 [==============================] - 3s 566us/step - loss: 0.8482 - mean_absolute_error: 0.7449
# Epoch 7/50
# 5681/5681 [==============================] - 3s 575us/step - loss: 0.8380 - mean_absolute_error: 0.7401
# Epoch 8/50
# 5681/5681 [==============================] - 3s 574us/step - loss: 0.8337 - mean_absolute_error: 0.7357
# Epoch 9/50
# 5681/5681 [==============================] - 3s 565us/step - loss: 0.8320 - mean_absolute_error: 0.7351
# Epoch 10/50
# 5681/5681 [==============================] - 3s 573us/step - loss: 0.8345 - mean_absolute_error: 0.7352
# Epoch 11/50
# 5681/5681 [==============================] - 3s 582us/step - loss: 0.8143 - mean_absolute_error: 0.7276
# Epoch 12/50
# 5681/5681 [==============================] - 3s 573us/step - loss: 0.8013 - mean_absolute_error: 0.7251
# Epoch 13/50
# 5681/5681 [==============================] - 3s 573us/step - loss: 0.7977 - mean_absolute_error: 0.7214
# Epoch 14/50
# 5681/5681 [==============================] - 3s 576us/step - loss: 0.7881 - mean_absolute_error: 0.7191
# Epoch 15/50
# 5681/5681 [==============================] - 3s 567us/step - loss: 0.7739 - mean_absolute_error: 0.7094
# Epoch 16/50
# 5681/5681 [==============================] - 3s 567us/step - loss: 0.7626 - mean_absolute_error: 0.7051
# Epoch 17/50
# 5681/5681 [==============================] - 3s 583us/step - loss: 0.7599 - mean_absolute_error: 0.6999
# Epoch 18/50
# 5681/5681 [==============================] - 3s 569us/step - loss: 0.7568 - mean_absolute_error: 0.7002
# Epoch 19/50
# 5681/5681 [==============================] - 3s 572us/step - loss: 0.7418 - mean_absolute_error: 0.6917
# Epoch 20/50
# 5681/5681 [==============================] - 3s 577us/step - loss: 0.7271 - mean_absolute_error: 0.6877
# Epoch 21/50
# 5681/5681 [==============================] - 3s 576us/step - loss: 0.7206 - mean_absolute_error: 0.6821
# Epoch 22/50
# 5681/5681 [==============================] - 3s 580us/step - loss: 0.7196 - mean_absolute_error: 0.6835
# Epoch 23/50
# 5681/5681 [==============================] - 3s 568us/step - loss: 0.7109 - mean_absolute_error: 0.6796
# Epoch 24/50
# 5681/5681 [==============================] - 3s 582us/step - loss: 0.7136 - mean_absolute_error: 0.6786
# Epoch 25/50
# 5681/5681 [==============================] - 3s 575us/step - loss: 0.6930 - mean_absolute_error: 0.6656
# Epoch 26/50
# 5681/5681 [==============================] - 3s 573us/step - loss: 0.6975 - mean_absolute_error: 0.6723
# Epoch 27/50
# 5681/5681 [==============================] - 3s 569us/step - loss: 0.6924 - mean_absolute_error: 0.6692
# Epoch 28/50
# 5681/5681 [==============================] - 3s 569us/step - loss: 0.6822 - mean_absolute_error: 0.6608
# Epoch 29/50
# 5681/5681 [==============================] - 3s 574us/step - loss: 0.6804 - mean_absolute_error: 0.6642
# Epoch 30/50
# 5681/5681 [==============================] - 3s 574us/step - loss: 0.6844 - mean_absolute_error: 0.6657
# Epoch 31/50
# 5681/5681 [==============================] - 3s 574us/step - loss: 0.6792 - mean_absolute_error: 0.6630
# Epoch 32/50
# 5681/5681 [==============================] - 3s 567us/step - loss: 0.6753 - mean_absolute_error: 0.6620
# Epoch 33/50
# 5681/5681 [==============================] - 3s 578us/step - loss: 0.6640 - mean_absolute_error: 0.6573
# Epoch 34/50
# 5681/5681 [==============================] - 3s 574us/step - loss: 0.6571 - mean_absolute_error: 0.6525
# Epoch 35/50
# 5681/5681 [==============================] - 3s 575us/step - loss: 0.6558 - mean_absolute_error: 0.6511
# Epoch 36/50
# 5681/5681 [==============================] - 3s 572us/step - loss: 0.6574 - mean_absolute_error: 0.6519
# Epoch 37/50
# 5681/5681 [==============================] - 3s 567us/step - loss: 0.6588 - mean_absolute_error: 0.6527
# Epoch 38/50
# 5681/5681 [==============================] - 3s 567us/step - loss: 0.6436 - mean_absolute_error: 0.6429
# Epoch 39/50
# 5681/5681 [==============================] - 3s 570us/step - loss: 0.6453 - mean_absolute_error: 0.6443
# Epoch 40/50
# 5681/5681 [==============================] - 3s 576us/step - loss: 0.6477 - mean_absolute_error: 0.6486
# Epoch 41/50
# 5681/5681 [==============================] - 3s 575us/step - loss: 0.6483 - mean_absolute_error: 0.6481
# Epoch 42/50
# 5681/5681 [==============================] - 3s 575us/step - loss: 0.6303 - mean_absolute_error: 0.6383
# Epoch 43/50
# 5681/5681 [==============================] - 3s 574us/step - loss: 0.6346 - mean_absolute_error: 0.6388
# Epoch 44/50
# 5681/5681 [==============================] - 3s 574us/step - loss: 0.6275 - mean_absolute_error: 0.6333
# Epoch 45/50
# 5681/5681 [==============================] - 3s 571us/step - loss: 0.6269 - mean_absolute_error: 0.6381
# Epoch 46/50
# 5681/5681 [==============================] - 3s 576us/step - loss: 0.6340 - mean_absolute_error: 0.6347
# Epoch 47/50
# 5681/5681 [==============================] - 3s 567us/step - loss: 0.6281 - mean_absolute_error: 0.6360
# Epoch 48/50
# 5681/5681 [==============================] - 3s 561us/step - loss: 0.6171 - mean_absolute_error: 0.6336
# Epoch 49/50
# 5681/5681 [==============================] - 3s 576us/step - loss: 0.6143 - mean_absolute_error: 0.6283
# Epoch 50/50
# 5681/5681 [==============================] - 3s 574us/step - loss: 0.6112 - mean_absolute_error: 0.6290
# accuracy Score: 0.4612676056338028
# Kappa Score: 0.5810057241033858
#
# --------Fold 4--------
#
# Training Word2Vec Model...
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_33 (LSTM)               (None, 1, 300)            721200
# _________________________________________________________________
# lstm_34 (LSTM)               (None, 64)                93440
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 814,705
# Trainable params: 814,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5681/5681 [==============================] - 11s 2ms/step - loss: 1.4438 - mean_absolute_error: 0.9523
# Epoch 2/50
# 5681/5681 [==============================] - 3s 571us/step - loss: 0.9671 - mean_absolute_error: 0.7936
# Epoch 3/50
# 5681/5681 [==============================] - 3s 574us/step - loss: 0.9473 - mean_absolute_error: 0.7871
# Epoch 4/50
# 5681/5681 [==============================] - 3s 567us/step - loss: 0.9133 - mean_absolute_error: 0.7730
# Epoch 5/50
# 5681/5681 [==============================] - 3s 568us/step - loss: 0.8997 - mean_absolute_error: 0.7668
# Epoch 6/50
# 5681/5681 [==============================] - 3s 575us/step - loss: 0.8812 - mean_absolute_error: 0.7609
# Epoch 7/50
# 5681/5681 [==============================] - 3s 566us/step - loss: 0.8772 - mean_absolute_error: 0.7543
# Epoch 8/50
# 5681/5681 [==============================] - 3s 581us/step - loss: 0.8738 - mean_absolute_error: 0.7544
# Epoch 9/50
# 5681/5681 [==============================] - 3s 588us/step - loss: 0.8645 - mean_absolute_error: 0.7545
# Epoch 10/50
# 5681/5681 [==============================] - 3s 582us/step - loss: 0.8352 - mean_absolute_error: 0.7381
# Epoch 11/50
# 5681/5681 [==============================] - 3s 570us/step - loss: 0.8255 - mean_absolute_error: 0.7328
# Epoch 12/50
# 5681/5681 [==============================] - 3s 579us/step - loss: 0.8260 - mean_absolute_error: 0.7325
# Epoch 13/50
# 5681/5681 [==============================] - 3s 574us/step - loss: 0.8249 - mean_absolute_error: 0.7317
# Epoch 14/50
# 5681/5681 [==============================] - 3s 574us/step - loss: 0.8055 - mean_absolute_error: 0.7239
# Epoch 15/50
# 5681/5681 [==============================] - 3s 573us/step - loss: 0.7977 - mean_absolute_error: 0.7203
# Epoch 16/50
# 5681/5681 [==============================] - 3s 569us/step - loss: 0.7909 - mean_absolute_error: 0.7171
# Epoch 17/50
# 5681/5681 [==============================] - 3s 571us/step - loss: 0.8004 - mean_absolute_error: 0.7207
# Epoch 18/50
# 5681/5681 [==============================] - 3s 563us/step - loss: 0.7771 - mean_absolute_error: 0.7099
# Epoch 19/50
# 5681/5681 [==============================] - 3s 581us/step - loss: 0.7791 - mean_absolute_error: 0.7120
# Epoch 20/50
# 5681/5681 [==============================] - 3s 573us/step - loss: 0.7656 - mean_absolute_error: 0.7089
# Epoch 21/50
# 5681/5681 [==============================] - 3s 572us/step - loss: 0.7566 - mean_absolute_error: 0.7054
# Epoch 22/50
# 5681/5681 [==============================] - 3s 583us/step - loss: 0.7463 - mean_absolute_error: 0.6999
# Epoch 23/50
# 2112/5681 [==========>...................] - ETA: 2s - loss: 0.7908 - mean_absolute_error: 0.7182
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-6646929f8015> in <module>()
#      55
#      56     lstm_model = get_model()
# ---> 57     lstm_model.fit(trainDataVecs, y_train, batch_size=64, epochs=50)
#      58     #lstm_model.load_weights('./model_weights/final_lstm.h5')
#      59     y_pred = lstm_model.predict(testDataVecs)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
print("Average Kappa score after a 5-fold cross validation: ",np.around(np.array(results).mean(),decimals=4))

# %%
y_pred = lstm_model.predict(testDataVecs)

# %%
testDataVecs
# Out:
# array([[[ 0.01239487, -0.01188916,  0.01831267, ...,  0.01561015,
#          -0.00202623, -0.01447918]],
#
#        [[ 0.00886085, -0.01891984,  0.01325977, ..., -0.01021764,
#          -0.00867095, -0.00408809]],
#
#        [[-0.00801387, -0.02748003, -0.01006253, ...,  0.00467406,
#          -0.02715149, -0.00608379]],
#
#        ...,
#
#        [[ 0.01893982, -0.00500628,  0.06924731, ..., -0.00130825,
#           0.01859911, -0.00765246]],
#
#        [[ 0.01124506, -0.03013514,  0.07888698, ..., -0.03112999,
#           0.01339157,  0.007404  ]],
#
#        [[-0.00203399, -0.03132698,  0.0845804 , ..., -0.022351  ,
#           0.01306732,  0.0041873 ]]], dtype=float32)
